# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt 
from matplotlib import cm # Colormaps
# import matplotlib.colors as colors
import matplotlib.dates as mdates

fs_label = 16
parameters = {
                'axes.labelsize': fs_label,
                'axes.titlesize': fs_label+4,
                'xtick.labelsize': fs_label,
                'ytick.labelsize': fs_label, 
                'legend.fontsize': fs_label, 
                'lines.markersize': 10,
                'lines.linewidth': 3
             }
plt.rcParams.update(parameters)

# from datetime import date
import datetime as dt

# import locale
# locale.setlocale(locale.LC_TIME,"Danish")
# locale.setlocale(locale.LC_ALL,"Danish")

# %%
# np.datetime64('2021-03-29')

# %%
def test_correct(actual_cases, actual_tests, pr_num_tests):
    return actual_cases*(pr_num_tests/actual_tests)**0.7

# %%
def hosp_case_rate(hosp, case, screen):
    return hosp/(case - screen)

def screen(c1, c2):
    hosp1, case1, screen1 = c1
    #print(c1)
    #print(c2)
    #print(case1 - hosp1/hosp_case_rate(*c2))
    return case1 - hosp1/hosp_case_rate(*c2)

# %% [markdown]
# Antag at forskelle i tilsyneladende indlæggelsesrate
# (indlæggelse pr. case) alene skyldes forskelle i mørketal.
# Cases fundet udover dem, der skal til for at give samme
# indlæggelsesrate som Norge (?) må da skyldes øget testning.

# %%
df_tests = pd.read_csv("data/data_tests.csv")

dow = 7

df_cases= pd.read_csv("data/data_cases.csv")
df_cases["dateRep"] = pd.to_datetime(df_cases["dateRep"], format='%d/%m/%Y')
df_cases.rename(columns = {'dateRep':'date'}, inplace = True)
df_cases["year_week"] = [str(x) + "-W" + str(y) for x,y in zip(df_cases["year"], df_cases["date"].dt.week)]
df_cases["weekdate"] = [dt.datetime.strptime(d + '-' + str(dow), '%G-W%V-%u') for d in df_cases["year_week"]]

df_hosp = pd.read_csv("data/data_hosp.csv")
df_hosp["weekdate"] = [dt.datetime.strptime(d + '-' + str(dow), '%G-W%V-%u') for d in df_hosp["year_week"]]
df_hosp["date"] = pd.to_datetime(df_hosp["date"])#, format='%Y-%m-%d')

indicators = df_hosp.loc[df_hosp.country == "Sweden", "indicator"].unique()
print(indicators)
select = (df_hosp.country == "Norway") & (df_hosp.indicator == 'Daily hospital occupancy')
df_hosp.loc[select].head(10)
# Out:
# ['Daily hospital occupancy' 'Daily ICU occupancy'
#  'Weekly new ICU admissions per 100k']
#       country                 indicator       date year_week  value  \
# 14629  Norway  Daily hospital occupancy 2020-03-08  2020-W10    0.0
# 14630  Norway  Daily hospital occupancy 2020-03-09  2020-W11    2.0
# 14631  Norway  Daily hospital occupancy 2020-03-10  2020-W11    8.0
# 14632  Norway  Daily hospital occupancy 2020-03-11  2020-W11   13.0
# 14633  Norway  Daily hospital occupancy 2020-03-12  2020-W11   23.0
# 14634  Norway  Daily hospital occupancy 2020-03-13  2020-W11   27.0
# 14635  Norway  Daily hospital occupancy 2020-03-14  2020-W11   35.0
# 14636  Norway  Daily hospital occupancy 2020-03-15  2020-W11   41.0
# 14637  Norway  Daily hospital occupancy 2020-03-16  2020-W12   50.0
# 14638  Norway  Daily hospital occupancy 2020-03-17  2020-W12   68.0
#
#             source                                     url   weekdate
# 14629  Country_API  https://utvikler.helsedirektoratet.no/ 2020-03-08
# 14630  Country_API  https://utvikler.helsedirektoratet.no/ 2020-03-15
# 14631  Country_API  https://utvikler.helsedirektoratet.no/ 2020-03-15
# 14632  Country_API  https://utvikler.helsedirektoratet.no/ 2020-03-15
# 14633  Country_API  https://utvikler.helsedirektoratet.no/ 2020-03-15
# 14634  Country_API  https://utvikler.helsedirektoratet.no/ 2020-03-15
# 14635  Country_API  https://utvikler.helsedirektoratet.no/ 2020-03-15
# 14636  Country_API  https://utvikler.helsedirektoratet.no/ 2020-03-15
# 14637  Country_API  https://utvikler.helsedirektoratet.no/ 2020-03-22
# 14638  Country_API  https://utvikler.helsedirektoratet.no/ 2020-03-22

# %%
def hospitalizations(country):
    hosp = df_hosp.loc[df_hosp.country == country]
    # print(hosp)
    pop_105 = df_cases.loc[df_cases.countriesAndTerritories == country, "popData2020"].unique()[0]/(1e5)
    selection = (hosp["indicator"] == "Weekly new hospital admissions per 100k")
    #print(hosp.loc[selection])
    plotdata = pd.DataFrame(hosp.loc[selection].groupby(["weekdate"])["value"].sum().reset_index())
    plotdata.value = plotdata.value*pop_105
    return plotdata

def cases(country):
    cases = df_cases.loc[df_cases.countriesAndTerritories == country]
    selection = (df_cases.weekdate > "2021-03-07")
    plotdata = pd.DataFrame(cases.loc[selection].groupby(["weekdate"])["cases"].sum().reset_index())
    plotdata.rename(columns = {'cases':'value'}, inplace = True)
    return plotdata

def common_dates(dates1, dates2):
    return sorted(list(set(dates1).intersection(set(dates2))))

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,8), tight_layout=True)

ctrys = ["Denmark", "Norway"]

#plotdata = hospitalizations(c)
#ax.plot(plotdata.weekdate, plotdata.value, label="hospitalizations_" + c)
#print(plotdata.weekdate)

#plotdata = cases(c)
#ax.plot(plotdata.weekdate, plotdata.value, label="cases_" + c)
#print(plotdata.weekdate)

sig_dict = {}
plot_days = []

for c in ctrys:
    plot_days = common_dates(cases(c).weekdate, hospitalizations(c).weekdate)
    hosp = hospitalizations(c).loc[hospitalizations(c).weekdate.isin(plot_days), "value"]
    case = cases(c).loc[cases(c).weekdate.isin(plot_days), "value"]

    sig_dict[c] = [hosp.values, case.values, 0] 
    
    ax.plot(plot_days, hosp.values/case.values, label="hosp_case_ratio_" + c)

#ax.plot(plot_days, screen(sig_dict["Denmark"], sig_dict["Norway"]), label="screening")

ax.legend()

plt.xticks(rotation=90)
plt.xlim("2021-03-02", "2021-06-20")

hospitalizations("Norge")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4fc8a5d299bf> in <module>
# ----> 1 fig, ax = plt.subplots(1, 1, figsize=(16,8), tight_layout=True)
#       2
#       3 ctrys = ["Denmark", "Norway"]
#       4
#       5 #plotdata = hospitalizations(c)
#
# NameError: name 'plt' is not defined

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,8), tight_layout=True)

ctrys = ["Denmark", "Norway"]

#plotdata = hospitalizations(c)
#ax.plot(plotdata.weekdate, plotdata.value, label="hospitalizations_" + c)
#print(plotdata.weekdate)

#plotdata = cases(c)
#ax.plot(plotdata.weekdate, plotdata.value, label="cases_" + c)
#print(plotdata.weekdate)

sig_dict = {}
plot_days = []

for c in ctrys:
    plot_days = common_dates(cases(c).weekdate, hospitalizations(c).weekdate)
    hosp = hospitalizations(c).loc[hospitalizations(c).weekdate.isin(plot_days), "value"]
    case = cases(c).loc[cases(c).weekdate.isin(plot_days), "value"]

    sig_dict[c] = [hosp.values, case.values, 0] 
    
    #ax.plot(plot_days, hosp.values/case.values, label="hosp_case_ratio_" + c)

ax.plot(plot_days, screen(sig_dict["Denmark"], sig_dict["Norway"]), label="screening")

ax.legend()

plt.xticks(rotation=90)
plt.xlim("2021-03-02", "2021-06-20")
# Out:
# (18688.0, 18798.0)

# %%
def hosp_occ_day(country):
    hosp = df_hosp.loc[df_hosp.country == country]
    selection = (hosp["indicator"] == "Daily hospital occupancy")
    plotdata = hosp.loc[selection, ["date", "value"]]
    return plotdata

def cases_day(country):
    cases = df_cases.loc[df_cases.countriesAndTerritories == country]
    selection = (df_cases.date > "2021-03-01")
    plotdata = cases.loc[selection, ["date", "cases"]]
    plotdata.rename(columns = {'cases':'value'}, inplace = True)
    return plotdata

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,8), tight_layout=True)

ctrys = ["Denmark", "Norway"]

sig_dict = {}
plot_days = []

for c in ctrys:
    plot_days = common_dates(cases_day(c).date, hosp_occ_day(c).date)
    #print(plot_days)
    hosp = hosp_occ_day(c).loc[hosp_occ_day(c).date.isin(plot_days), "value"]
    case = cases_day(c).loc[cases_day(c).date.isin(plot_days), "value"]

    sig_dict[c] = [hosp.values, case.values, 0] 
    
    ax.plot(plot_days, hosp.values/case.values, label="hosp_case_ratio_" + c)

# ax.plot(plot_days, screen(sig_dict["Denmark"], sig_dict["Norway"]), label="screening")

ax.legend()

plt.xticks(rotation=90)
#plt.xlim("2021-03-02", "2021-06-20")
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in true_divide
#   app.launch_new_instance()
# (array([18687., 18701., 18718., 18732., 18748., 18762.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,8), tight_layout=True)

ctrys = ["Denmark", "Norway"]

sig_dict = {}
plot_days = []

for c in ctrys:
    plot_days = common_dates(cases_day(c).date, hosp_occ_day(c).date)
    #print(plot_days)
    hosp = hosp_occ_day(c).loc[hosp_occ_day(c).date.isin(plot_days), "value"]
    case = cases_day(c).loc[cases_day(c).date.isin(plot_days), "value"]

    sig_dict[c] = [hosp.values, case.values, 0] 
    
    # ax.plot(plot_days, hosp.values/case.values, label="hosp_case_ratio_" + c)

ax.plot(plot_days, screen(sig_dict["Denmark"], sig_dict["Norway"]), label="screening")

ax.legend()

plt.xticks(rotation=90)
#plt.xlim("2021-03-02", "2021-06-20")
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# (array([18687., 18701., 18718., 18732., 18748., 18762.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#c="Denmark"
#cases_day(c).date.values

# %%
#hosp_occ_day(c).date.values

# %%
#common_dates(cases_day(c).date.values, hosp_occ_day(c).date.values)
