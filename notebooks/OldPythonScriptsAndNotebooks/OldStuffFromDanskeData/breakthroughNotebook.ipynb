# %%
# Main notebook for breakthrough infections
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.min_rows', 50)
import seaborn as sns


import matplotlib.pyplot as plt
# %matplotlib widget
plt.rcParams['figure.figsize'] = (12,8)
# plt.rcParams["image.cmap"] = "Dark2"
# plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Dark2.colors)
plt.rcParams["image.cmap"] = "tab10"
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.tab10.colors)
fs_label = 16
parameters = {
                'axes.labelsize': fs_label,
                'axes.titlesize': fs_label+4,
                'xtick.labelsize': fs_label,
                'ytick.labelsize': fs_label, 
                'legend.fontsize': fs_label, 
                'lines.markersize': 10,
                'lines.linewidth': 3
             }
plt.rcParams.update(parameters)
# %matplotlib widget  
# plt.style.use('ggplot')
import matplotlib.colors as colors
# cmap = plt.cm.get_cmap('Dark2',len(ageGroups))
from matplotlib import cm # Colormaps

import locale
import matplotlib.dates as mdates
locale.setlocale(locale.LC_TIME,"Danish")
# ax = plt.gca()
# ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b\n%Y'))
# # ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y \n %B'))

import os
# import csv
import math


from datetime import date


saveFigures = True
# saveFigures = False
print('saveFigures is set to: '+str(saveFigures))

print('Done loading packages')

def rnMean(data,meanWidth):
    return np.convolve(data, np.ones(meanWidth)/meanWidth, mode='valid')
def rnTime(t,meanWidth):
    return t[math.floor(meanWidth/2):-math.ceil(meanWidth/2)+1]
# Out:
# saveFigures is set to: True
# Done loading packages

# %%
# Define datapath and load
ssidatapath = "ssi_data"
rootdir = os.getcwd() +"\\" + ssidatapath


# Data is (only) in the file from the most recent tuesday. 
# Should be made smarter, but here hardcoded
tuePath = 'overvaagningsdata-covid19-14092021-jrhb'
# tuePath = 'SSI_data_2021-09-14'
# tuePath = 'SSI_data_2021-09-28'
# tuePath = 'SSI_data_2021-10-05'
# tuePath = 'SSI_data_2021-10-12'
# tuePath = 'SSI_data_2021-10-19'
# tuePath = 'SSI_data_2021-10-26'
# tuePath = 'SSI_data_2021-11-02'
# tuePath = 'SSI_data_2021-11-09'
tuePath = 'SSI_data_2021-11-16'

dirPath = rootdir + '\\' + tuePath + '\\'

df1 = pd.read_csv(dirPath+'gennembrudsinfektioner_table1.csv',delimiter=';')
df2_C = pd.read_csv(dirPath+'gennembrudsinfektioner_table2_antal_cases.csv',delimiter=';')
df2_H = pd.read_csv(dirPath+'gennembrudsinfektioner_table2_antal_indlagte.csv',delimiter=';')
df2_R = pd.read_csv(dirPath+'gennembrudsinfektioner_table2_antal_repositive.csv',delimiter=';')
df3 = pd.read_csv(dirPath+'gennembrudsinfektioner_table2_incidence_alle.csv',delimiter=';')
df3_C = pd.read_csv(dirPath+'gennembrudsinfektioner_table2_incidence_cases.csv',delimiter=';')
df3_H = pd.read_csv(dirPath+'gennembrudsinfektioner_table2_incidence_indlagte.csv',delimiter=';')

# %%
# df3_H.replace(',','.')
df2_H
# Out:
#    Aldersgruppe  Uge 45_Ingen vaccination  Uge 45_Første vaccination  \
# 0         12-15                         3                          0
# 1         16-19                         2                          0
# 2         20-29                        20                          1
# 3         30-39                        30                          1
# 4         40-49                        22                          4
# 5         50-59                        18                          3
# 6         60-64                         9                          1
# 7         65-69                         6                          1
# 8         70-79                         9                          2
# 9           80+                         9                          2
# 10          12+                       128                         15
#
#     Uge 45_Anden vaccination  Uge 45_Fuld vaccineeffekt  \
# 0                          0                          0
# ...

# %%
# print(df2_H['Uge 33_Fuld vaccineeffekt'])
# # print(df3_H['Uge 33_Fuld vaccineeffekt'])
# # print(np.multiply(df2_H['Uge 33_Fuld vaccineeffekt'].values,df3_H['Uge 33_Fuld vaccineeffekt'].values)) 
# print(pd.to_numeric(df3_H['Uge 33_Fuld vaccineeffekt'].str.replace(',','.')))
# print(df3_H['Uge 33_Ingen vaccination']) 
# df3_H
# print(100000* df2_H['Uge 33_Fuld vaccineeffekt'] / pd.to_numeric(df3_H['Uge 33_Fuld vaccineeffekt'].str.replace(',','.')))
# print(100000* df2_C['Uge 36_Ingen vaccination'] / pd.to_numeric(df3_C['Uge 36_Ingen vaccination'].str.replace(',','.')))
# print(100000* df2_H['Uge 36_Ingen vaccination'] / pd.to_numeric(df3_H['Uge 36_Ingen vaccination'].str.replace(',','.')))
# popSize = (100000* df2_C['Uge 34_Ingen vaccination'] / pd.to_numeric(df3_C['Uge 34_Ingen vaccination'].str.replace(',','.')))
# print(popSize * 18 / 100000)
# popSize = (100000* df2_C['Uge 35_Ingen vaccination'] / pd.to_numeric(df3_C['Uge 35_Ingen vaccination'].str.replace(',','.')))
# print(popSize * 18 / 100000)
# popSize = (100000* df2_C['Uge 36_Ingen vaccination'] / pd.to_numeric(df3_C['Uge 36_Ingen vaccination'].str.replace(',','.')))
# print(popSize * 27 / 100000)
# popSize = (100000* df2_C['Uge 37_Ingen vaccination'] / pd.to_numeric(df3_C['Uge 37_Ingen vaccination'].str.replace(',','.')))
# print(popSize * 46 / 100000)


popSize = (100000* df2_C['Uge 34_Fuld vaccineeffekt'] / pd.to_numeric(df3_C['Uge 34_Fuld vaccineeffekt'].str.replace(',','.')))
print(popSize * 2 / 100000)
popSize = (100000* df2_C['Uge 35_Fuld vaccineeffekt'] / pd.to_numeric(df3_C['Uge 35_Fuld vaccineeffekt'].str.replace(',','.')))
print(popSize * 1 / 100000)
popSize = (100000* df2_C['Uge 36_Fuld vaccineeffekt'] / pd.to_numeric(df3_C['Uge 36_Fuld vaccineeffekt'].str.replace(',','.')))
print(popSize * 4 / 100000)
popSize = (100000* df2_C['Uge 37_Fuld vaccineeffekt'] / pd.to_numeric(df3_C['Uge 37_Fuld vaccineeffekt'].str.replace(',','.')))
print(popSize * 2 / 100000)
# Out:
# 0      0.233463
# 1      3.630952
# 2      6.395112
# 3      4.449704
# 4     10.978836
# 5     13.779904
# 6      6.262626
# 7      5.945946
# 8     10.922509
# 9      5.355649
# 10    67.909091
# Name: Uge 34_Fuld vaccineeffekt, dtype: float64
# 0      0.441176
# 1      1.939163
# 2      4.148148
# 3      3.483146
# 4      5.821678
# 5      6.952141
# 6      3.149351
# 7      2.979592
# 8      5.476190
# 9      2.682927
# 10    37.035040
# Name: Uge 35_Fuld vaccineeffekt, dtype: float64
# 0       3.157895
# 1       8.000000
# 2      18.707692
# 3      16.746667
# 4      23.801653
# 5      27.968750
# 6      12.598425
# 7      11.904762
# 8      21.886792
# 9      10.720000
# 10    155.441176
# Name: Uge 36_Fuld vaccineeffekt, dtype: float64
# 0      2.222222
# 1      4.067797
# 2      9.952153
# 3      9.185185
# 4     12.061069
# 5     14.000000
# 6      6.315789
# 7      5.954198
# 8     10.921053
# 9      5.333333
# 10    80.315789
# ...

# %%
df2_C
# Out:
#    Aldersgruppe  Uge 45_Ingen vaccination  Uge 45_Første vaccination  \
# 0         12-15                       927                         95
# 1         16-19                       335                         35
# 2         20-29                      1125                        124
# 3         30-39                      1027                         98
# 4         40-49                       682                         54
# 5         50-59                       338                         16
# 6         60-64                        56                          3
# 7         65-69                        34                          3
# 8         70-79                        31                          5
# 9           80+                        17                          3
# 10          12+                      4572                        436
#
#     Uge 45_Anden vaccination  Uge 45_Fuld vaccineeffekt  \
# 0                        239                        234
# ...

# %% [markdown]
# # Make some plots of file 1

# %%
allWeeks = df1['Ugenummer'].apply(lambda x: int(x[-2:]))
# allWeeks
# allWeeks
# Uge 36: 07-09-2021

weekOffset = allWeeks - 36
# weekOffset
allDates = weekOffset.apply(lambda x:np.datetime64('2021-09-07') + np.timedelta64(x*7,'D'))
# allDates

print(df1.columns)
df1.head()
# Out:
# Index(['Ugenummer', 'antal_personer_alle_Ingen vaccination',
#        'antal_personer_alle_Første vaccination',
#        'antal_personer_alle_Anden vaccination',
#        'antal_personer_alle_Fuld vaccineeffekt',
#        'antal_personer_Ingen vaccination', 'antal_personer_Første vaccination',
#        'antal_personer_Anden vaccination', 'antal_personer_Fuld vaccineeffekt',
#        'antal_cases_Ingen vaccination', 'antal_cases_Første vaccination',
#        'antal_cases_Anden vaccination', 'antal_cases_Fuld vaccineeffekt',
#        'antal_tests_Ingen vaccination', 'antal_tests_Første vaccination',
#        'antal_tests_Anden vaccination', 'antal_tests_Fuld vaccineeffekt',
#        'antal_tests_total_Ingen vaccination',
#        'antal_tests_total_Første vaccination',
#        'antal_tests_total_Anden vaccination',
#        'antal_tests_total_Fuld vaccineeffekt',
#        'antal_repositive_Ingen vaccination',
#        'antal_repositive_Første vaccination',
# ...

# %%
print(df2_C['Uge 34_Fuld vaccineeffekt'].iloc[8])
print(df2_C['Uge 35_Fuld vaccineeffekt'].iloc[8])
print(df2_C['Uge 36_Fuld vaccineeffekt'].iloc[8])
print(df2_C['Uge 37_Fuld vaccineeffekt'].iloc[8])
# Out:
# 148
# 115
# 116
# 83

# %%
fig,(ax1,ax2) = plt.subplots(2,1,sharex=True)

ax1.plot(allWeeks,df1['antal_personer_alle_Ingen vaccination'],color='xkcd:light red')
ax1.plot(allWeeks,df1['antal_personer_alle_Første vaccination'],color='xkcd:light blue')
ax1.plot(allWeeks,df1['antal_personer_alle_Anden vaccination'],color='xkcd:blue')
ax1.plot(allWeeks,df1['antal_personer_alle_Fuld vaccineeffekt'],color='xkcd:dark blue')



# ax2.fill_between(allWeeks,df1['antal_personer_alle_Ingen vaccination'] + df1['antal_personer_alle_Første vaccination']+df1['antal_personer_alle_Anden vaccination'],color='xkcd:blue')
# ax2.fill_between(allWeeks,df1['antal_personer_alle_Ingen vaccination'] + df1['antal_personer_alle_Første vaccination'],color='xkcd:light blue')
# ax2.fill_between(allWeeks,df1['antal_personer_alle_Ingen vaccination'],color='r')

# ax2.fill_between(allWeeks,df1['antal_personer_alle_Ingen vaccination'] + df1['antal_personer_alle_Første vaccination']+df1['antal_personer_alle_Fuld vaccineeffekt'],
#                           df1['antal_personer_alle_Ingen vaccination'] + df1['antal_personer_alle_Første vaccination']+df1['antal_personer_alle_Anden vaccination'],color='xkcd:dark blue')

vaccNone = df1['antal_personer_alle_Ingen vaccination']
vaccOnce = df1['antal_personer_alle_Første vaccination']
vaccBoth = df1['antal_personer_alle_Anden vaccination']
vaccFull = df1['antal_personer_alle_Fuld vaccineeffekt']
vaccNotFullYet = vaccBoth-vaccFull

ax2.fill_between(allWeeks,vaccNone,color='xkcd:light red',label='Uvaccineret')
ax2.fill_between(allWeeks,vaccOnce+vaccNone,vaccNone,color='xkcd:light blue',label='Første dosis')
ax2.fill_between(allWeeks,vaccBoth+vaccOnce+vaccNone,vaccOnce+vaccNone,color='xkcd:dark blue',label='Anden dosis, fuld effekt')
ax2.fill_between(allWeeks,vaccNotFullYet+vaccOnce+vaccNone,vaccOnce+vaccNone,color='xkcd:blue',label='Anden dosis, afventer effekt')


ax1.set_ylim(bottom=0)
ax2.set_ylim(bottom=0,top=6e6)

ax1.set_xlim(left=allWeeks.min(),right=allWeeks.max())
ax2.legend()

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig,(ax1,ax2) = plt.subplots(2,1,sharex=True)


caseNone = df1['antal_cases_Ingen vaccination']
caseOnce = df1['antal_cases_Første vaccination']
caseBoth = df1['antal_cases_Anden vaccination']
caseFull = df1['antal_cases_Fuld vaccineeffekt']
caseNotFullYet = caseBoth-caseFull

# ax1.plot(allWeeks,caseNone)
# ax1.plot(allWeeks,caseNone+caseOnce)
# # ax1.plot(allWeeks,caseBoth+caseNone+caseOnce)
# ax1.plot(allWeeks,caseFull+caseNone+caseOnce)

ax1.fill_between(allWeeks,caseNone,color='xkcd:light red',label='Uvaccineret')
ax1.fill_between(allWeeks,caseOnce+caseNone,caseNone,color='xkcd:light blue',label='Første dosis')
ax1.fill_between(allWeeks,caseBoth+caseOnce+caseNone,caseOnce+caseNone,color='xkcd:dark blue',label='Anden dosis, fuld effekt')
ax1.fill_between(allWeeks,caseNotFullYet+caseOnce+caseNone,caseOnce+caseNone,color='xkcd:blue',label='Anden dosis, afventer effekt')

caseAll = caseNone+caseOnce+caseBoth
ax2.fill_between(allWeeks,np.divide(caseNone,caseAll),color='xkcd:light red',label='Uvaccineret')
ax2.fill_between(allWeeks,np.divide(caseOnce+caseNone,caseAll),np.divide(caseNone,caseAll),color='xkcd:light blue',label='Første dosis')
ax2.fill_between(allWeeks,np.divide(caseBoth+caseOnce+caseNone,caseAll),np.divide(caseOnce+caseNone,caseAll),color='xkcd:dark blue',label='Anden dosis, fuld effekt')
ax2.fill_between(allWeeks,np.divide(caseNotFullYet+caseOnce+caseNone,caseAll),np.divide(caseOnce+caseNone,caseAll),color='xkcd:blue',label='Anden dosis, afventer effekt')


ax1.set_ylim(bottom=0)
ax2.set_ylim(bottom=0,top=1)

ax1.set_xlim(left=allWeeks.min(),right=allWeeks.max())
ax2.legend(loc='upper left')

ax1.set_ylabel('Cases')
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(12,8),sharex=True)


bgColor = 'lightgrey'
fig.patch.set_facecolor(bgColor)
ax1.set_facecolor(bgColor)
ax2.set_facecolor(bgColor)


hospNone = df1['antal_indlagte_Ingen vaccination']
hospOnce = df1['antal_indlagte_Første vaccination']
hospBoth = df1['antal_indlagte_Anden vaccination']
hospFull = df1['antal_indlagte_Fuld vaccineeffekt']
hospNotFullYet = hospBoth-hospFull

# ax1.plot(allDates,hospNone)
# ax1.plot(allDates,hospNone+hospOnce)
# # ax1.plot(allDates,hospBoth+hospNone+hospOnce)
# ax1.plot(allDates,hospFull+hospNone+hospOnce)

ax1.fill_between(allDates,hospNone,color='xkcd:light red',label='Uvaccineret')
ax1.fill_between(allDates,hospOnce+hospNone,hospNone,color='xkcd:light blue',label='Første dosis')
ax1.fill_between(allDates,hospBoth+hospOnce+hospNone,hospOnce+hospNone,color='xkcd:dark blue',label='Anden dosis,\nFuld effekt')
ax1.fill_between(allDates,hospNotFullYet+hospOnce+hospNone,hospOnce+hospNone,color='xkcd:blue',label='Anden dosis,\nAfventer effekt')

hospAll = hospNone+hospOnce+hospBoth
ax2.fill_between(allDates,100*np.divide(hospNone,hospAll),color='xkcd:light red',label='Uvaccineret')
ax2.fill_between(allDates,100*np.divide(hospOnce+hospNone,hospAll),100*np.divide(hospNone,hospAll),color='xkcd:light blue',label='Første dosis')
ax2.fill_between(allDates,100*np.divide(hospBoth+hospOnce+hospNone,hospAll),100*np.divide(hospOnce+hospNone,hospAll),color='xkcd:dark blue',label='Anden dosis, fuld effekt')
ax2.fill_between(allDates,100*np.divide(hospNotFullYet+hospOnce+hospNone,hospAll),100*np.divide(hospOnce+hospNone,hospAll),color='xkcd:blue',label='Anden dosis, afventer effekt')

ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d. %b'))

ax1.set_ylim(bottom=0)
ax2.set_ylim(bottom=0,top=100)

# Draw weekends
firstSunday = np.datetime64('2021-01-03')
numWeeks = 52
for k in range(0,numWeeks):
    curSunday = firstSunday + np.timedelta64(7*k,'D')
    ax1.axvspan(curSunday-np.timedelta64(1,'D')-np.timedelta64(12,'h'),curSunday+np.timedelta64(12,'h'),zorder=-1,facecolor='grey',label=int(k==0)*'Weekend')
    ax2.axvspan(curSunday-np.timedelta64(1,'D')-np.timedelta64(12,'h'),curSunday+np.timedelta64(12,'h'),zorder=-1,facecolor='grey')


# ax1.set_xlim(left=np.datetime64('2021-05-19'))
ax1.set_xlim(left=np.datetime64('2021-07-15'))
ax1.set_xlim(right=np.datetime64('2021-11-15'))

ax1.set_ylabel('Antal nyindlæggelser\n(per uge)')
ax2.set_ylabel('Andel ud af alle nyindlæggelser [%]')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d\n%b'))

# ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax1.legend(loc='upper left')

# ax1.set_ylabel('Antal nyindlæggelser')
# ax2.set_ylabel('Fordeling')

# ax1.set_xlim(left=allDates.min(),right=allDates.max())
# ax2.legend()
plt.tight_layout()

plt.savefig('figs/VaccHospFordeling')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(12,8),sharex=True)


bgColor = 'lightgrey'
fig.patch.set_facecolor(bgColor)
ax1.set_facecolor(bgColor)
ax2.set_facecolor(bgColor)


hospNone = df1['antal_indlagte_Ingen vaccination']/7
hospOnce = df1['antal_indlagte_Første vaccination']/7
hospBoth = df1['antal_indlagte_Anden vaccination']/7
hospFull = df1['antal_indlagte_Fuld vaccineeffekt']/7
hospNotFullYet = hospBoth-hospFull

# ax1.plot(allDates,hospNone)
# ax1.plot(allDates,hospNone+hospOnce)
# # ax1.plot(allDates,hospBoth+hospNone+hospOnce)
# ax1.plot(allDates,hospFull+hospNone+hospOnce)

ax1.fill_between(allDates,hospNone,color='xkcd:light red',label='Uvaccineret')
ax1.fill_between(allDates,hospOnce+hospNone,hospNone,color='xkcd:light blue',label='Første dosis')
ax1.fill_between(allDates,hospBoth+hospOnce+hospNone,hospOnce+hospNone,color='xkcd:dark blue',label='Anden dosis,\nFuld effekt')
ax1.fill_between(allDates,hospNotFullYet+hospOnce+hospNone,hospOnce+hospNone,color='xkcd:blue',label='Anden dosis,\nAfventer effekt')

hospAll = hospNone+hospOnce+hospBoth
ax2.fill_between(allDates,100*np.divide(hospNone,hospAll),color='xkcd:light red',label='Uvaccineret')
ax2.fill_between(allDates,100*np.divide(hospOnce+hospNone,hospAll),100*np.divide(hospNone,hospAll),color='xkcd:light blue',label='Første dosis')
ax2.fill_between(allDates,100*np.divide(hospBoth+hospOnce+hospNone,hospAll),100*np.divide(hospOnce+hospNone,hospAll),color='xkcd:dark blue',label='Anden dosis, fuld effekt')
ax2.fill_between(allDates,100*np.divide(hospNotFullYet+hospOnce+hospNone,hospAll),100*np.divide(hospOnce+hospNone,hospAll),color='xkcd:blue',label='Anden dosis, afventer effekt')

ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d. %b'))

ax1.set_ylim(bottom=0)
ax2.set_ylim(bottom=0,top=100)

# Draw weekends
firstSunday = np.datetime64('2021-01-03')
numWeeks = 52
for k in range(0,numWeeks):
    curSunday = firstSunday + np.timedelta64(7*k,'D')
    ax1.axvspan(curSunday-np.timedelta64(1,'D')-np.timedelta64(12,'h'),curSunday+np.timedelta64(12,'h'),zorder=-1,facecolor='grey',label=int(k==0)*'Weekend')
    ax2.axvspan(curSunday-np.timedelta64(1,'D')-np.timedelta64(12,'h'),curSunday+np.timedelta64(12,'h'),zorder=-1,facecolor='grey')


# ax1.set_xlim(left=np.datetime64('2021-05-19'))
ax1.set_xlim(left=np.datetime64('2021-07-15'))
ax1.set_xlim(right=np.datetime64('2021-11-15'))

ax1.set_ylabel('Antal nyindlæggelser\n(per dag)')
ax2.set_ylabel('Andel ud af alle nyindlæggelser [%]')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d\n%b'))

# ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax1.legend(loc='upper left')

ax1.set_ylim([0,70])

# ax1.set_ylabel('Antal nyindlæggelser')
# ax2.set_ylabel('Fordeling')

# ax1.set_xlim(left=allDates.min(),right=allDates.max())
# ax2.legend()
plt.tight_layout()

plt.savefig('figs/VaccHospFordelingDaily')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df2_C.columns
# Out:
# Index(['Aldersgruppe', 'Uge 45_Ingen vaccination', 'Uge 45_Første vaccination',
#        'Uge 45_Anden vaccination', 'Uge 45_Fuld vaccineeffekt',
#        'Uge 44_Ingen vaccination', 'Uge 44_Første vaccination',
#        'Uge 44_Anden vaccination', 'Uge 44_Fuld vaccineeffekt',
#        'Uge 43_Ingen vaccination', 'Uge 43_Første vaccination',
#        'Uge 43_Anden vaccination', 'Uge 43_Fuld vaccineeffekt',
#        'Uge 42_Ingen vaccination', 'Uge 42_Første vaccination',
#        'Uge 42_Anden vaccination', 'Uge 42_Fuld vaccineeffekt',
#        'Uge 41_Ingen vaccination', 'Uge 41_Første vaccination',
#        'Uge 41_Anden vaccination', 'Uge 41_Fuld vaccineeffekt',
#        'Uge 40_Ingen vaccination', 'Uge 40_Første vaccination',
#        'Uge 40_Anden vaccination', 'Uge 40_Fuld vaccineeffekt',
#        'Uge 39_Ingen vaccination', 'Uge 39_Første vaccination',
#        'Uge 39_Anden vaccination', 'Uge 39_Fuld vaccineeffekt',
# ...

# %% [markdown]
# # Aldersinddelt

# %%
# df2_H['Uge 38_Ingen vaccination']/
df3_H['Uge 38_Ingen vaccination']
# Out:
# 0        0
# 1      2,9
# 2      1,8
# 3        5
# 4      5,1
# 5      9,2
# 6     11,7
# 7     16,1
# 8     23,8
# 9     21,4
# 10       5
# Name: Uge 38_Ingen vaccination, dtype: object

# %%
# Flip dataframe to be like df1
casedf = pd.DataFrame()
casedf_once = pd.DataFrame()
casedf_both = pd.DataFrame()
casedf_full = pd.DataFrame()
casedf_none = pd.DataFrame()

weekNames = df1.Ugenummer
casedf['Ugenummer'] = weekNames
casedf_none['Ugenummer'] = weekNames
casedf_once['Ugenummer'] = weekNames
casedf_both['Ugenummer'] = weekNames
casedf_full['Ugenummer'] = weekNames

for k in range(0,len(df2_C)):
    curRow = df2_C.loc[k]
    curAge = df2_C.loc[k,'Aldersgruppe']
    print(curAge)
    
    curNone = []
    curOnce = []
    curBoth = []
    curFull = []
    for curW in weekNames:
        # print(curW)
        
        thisNone = curRow[curW+'_Ingen vaccination']
        curNone.append(thisNone)
        
        thisOnce = curRow[curW+'_Første vaccination']
        curOnce.append(thisOnce)
        
        thisBoth = curRow[curW+'_Anden vaccination']
        curBoth.append(thisBoth)
        
        thisFull = curRow[curW+'_Fuld vaccineeffekt']
        curFull.append(thisFull)
    
    # Add to dataframe
    casedf[curAge+'_Ingen vaccination'] = curNone
    casedf[curAge+'_Første vaccination'] = curOnce
    casedf[curAge+'_Anden vaccination'] = curBoth 
    casedf[curAge+'_Fuld vaccineeffekt'] = curFull
    
    # Add to smaller dataframes as well
    casedf_none[curAge] = curNone
    casedf_once[curAge] = curOnce
    casedf_both[curAge] = curBoth 
    casedf_full[curAge] = curFull
    

# df2_C
# curRow
casedf
# cur
# Out:
# 12-15
# 16-19
# 20-29
# 30-39
# 40-49
# 50-59
# 60-64
# 65-69
# 70-79
# 80+
# 12+
#    Ugenummer  12-15_Ingen vaccination  12-15_Første vaccination  \
# 0     Uge 45                      927                        95
# 1     Uge 44                      642                        47
# 2     Uge 43                      510                        19
# 3     Uge 42                      374                        20
# 4     Uge 41                      228                         8
# 5     Uge 40                      222                        10
# 6     Uge 39                      162                        13
# 7     Uge 38                      171                        14
# 8     Uge 37                      148                        12
# 9     Uge 36                      183                        29
# 10    Uge 35                      330                        75
# 11    Uge 34                      493                       126
# ...

# %%
for curAge in casedf_none.columns[1:]:

    fig,ax1 = plt.subplots()

    # curAge = '20-29'
    ax1.plot(allDates,casedf_none[curAge],'r',label='Uvaccinerede')
    ax1.plot(allDates,casedf_once[curAge],color='xkcd:light blue',label='Første dosis')
    # ax1.plot(allDates,casedf_both[curAge])
    ax1.plot(allDates,casedf_full[curAge],color='xkcd:dark blue',label='Anden dosis (og fuld vaccineeffekt)')
 
    ax1.set_ylim(bottom=0)
    ax1.set_xlim([allDates.min(),allDates.max()])
    ax1.legend()
    ax1.set_title('Tilfælde, '+curAge)
    
    # ax1.set_xlabel('Ugenummer')
    ax1.set_ylabel('Antal')
    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d. %b'))

    plt.tight_layout()
    if saveFigures:
        plt.savefig('figs/gennembrud/Case'+curAge)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ...

# %%
# Flip dataframe to be like df1
hospdf = pd.DataFrame()
hospdf_once = pd.DataFrame()
hospdf_both = pd.DataFrame()
hospdf_full = pd.DataFrame()
hospdf_none = pd.DataFrame()

weekNames = df1.Ugenummer
hospdf['Ugenummer'] = weekNames
hospdf_none['Ugenummer'] = weekNames
hospdf_once['Ugenummer'] = weekNames
hospdf_both['Ugenummer'] = weekNames
hospdf_full['Ugenummer'] = weekNames

for k in range(0,len(df2_H)):
    curRow = df2_H.loc[k]
    curAge = df2_H.loc[k,'Aldersgruppe']
    
    curNone = []
    curOnce = []
    curBoth = []
    curFull = []
    for curW in weekNames:
        # print(curW)
        
        thisNone = curRow[curW+'_Ingen vaccination']
        curNone.append(thisNone)
        
        thisOnce = curRow[curW+'_Første vaccination']
        curOnce.append(thisOnce)
        
        thisBoth = curRow[curW+'_Anden vaccination']
        curBoth.append(thisBoth)
        
        thisFull = curRow[curW+'_Fuld vaccineeffekt']
        curFull.append(thisFull)
    
    # Add to dataframe
    hospdf[curAge+'_Ingen vaccination'] = curNone
    hospdf[curAge+'_Første vaccination'] = curOnce
    hospdf[curAge+'_Anden vaccination'] = curBoth 
    hospdf[curAge+'_Fuld vaccineeffekt'] = curFull
    
    # Add to smaller dataframes as well
    hospdf_none[curAge] = curNone
    hospdf_once[curAge] = curOnce
    hospdf_both[curAge] = curBoth 
    hospdf_full[curAge] = curFull
    

# df2_H
# curRow
hospdf
# cur
# Out:
#    Ugenummer  12-15_Ingen vaccination  12-15_Første vaccination  \
# 0     Uge 45                        3                         0
# 1     Uge 44                        3                         0
# 2     Uge 43                        3                         0
# 3     Uge 42                        1                         0
# 4     Uge 41                        0                         0
# 5     Uge 40                        2                         0
# 6     Uge 39                        0                         0
# 7     Uge 38                        0                         0
# 8     Uge 37                        0                         0
# 9     Uge 36                        1                         0
# 10    Uge 35                        4                         0
# 11    Uge 34                        3                         1
# 12    Uge 33                        2                         0
# 13    Uge 32                        4                         1
# ...

# %%
for curAge in hospdf_none.columns[1:]:

    fig,ax1 = plt.subplots()

    # curAge = '20-29'
    ax1.plot(allDates,hospdf_none[curAge],'r',label='Uvaccinerede')
    ax1.plot(allDates,hospdf_once[curAge],color='xkcd:light blue',label='Første dosis')
    # ax1.plot(allDates,hospdf_both[curAge])
    ax1.plot(allDates,hospdf_full[curAge],color='xkcd:dark blue',label='Anden dosis (og fuld vaccineeffekt)')
 
    ax1.set_ylim(bottom=0)
    ax1.set_xlim([allDates.min(),allDates.max()])
    ax1.legend()
    ax1.set_title('Indlæggelser, '+curAge)

    # ax1.set_xlabel('Dato')
    ax1.set_ylabel('Antal')
    
    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d. %b'))
    
    plt.tight_layout()
    
    if saveFigures:
        plt.savefig('figs/gennembrud/Hosp'+curAge)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <ipython-input-19-0f2b5c4685c6>:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig,ax1 = plt.subplots()
# ...

# %%
df3_C
# Out:
#    Aldersgruppe Uge 45_Ingen vaccination Uge 45_Første vaccination  \
# 0         12-15                   1468,5                     874,5
# 1         16-19                   1075,1                     895,8
# 2         20-29                      753                     745,9
# 3         30-39                    806,2                     667,1
# 4         40-49                    933,3                     830,6
# 5         50-59                    658,4                     405,7
# 6         60-64                    342,7                     257,1
# 7         65-69                    286,8                     402,7
# 8         70-79                    193,7                       540
# 9           80+                    193,6                     414,4
# 10          12+                    833,6                     725,6
#
#    Uge 45_Anden vaccination Uge 45_Fuld vaccineeffekt  \
# 0                     132,1                       132
# ...

# %%
# Flip dataframe to be like df1
incidf = pd.DataFrame()
incidf_once = pd.DataFrame()
incidf_both = pd.DataFrame()
incidf_full = pd.DataFrame()
incidf_none = pd.DataFrame()

weekNames = df1.Ugenummer
incidf['Ugenummer'] = weekNames
incidf_none['Ugenummer'] = weekNames
incidf_once['Ugenummer'] = weekNames
incidf_both['Ugenummer'] = weekNames
incidf_full['Ugenummer'] = weekNames

for k in range(0,len(df3_C)):
    curRow = df3_C.loc[k]
    curAge = df3_C.loc[k,'Aldersgruppe']
    
    curNone = []
    curOnce = []
    curBoth = []
    curFull = []
    for curW in weekNames:
        # print(curW)
        
        thisNone = curRow[curW+'_Ingen vaccination']
        thisNone = pd.to_numeric(thisNone.replace(',','.'))
        curNone.append(thisNone)
        
        thisOnce = curRow[curW+'_Første vaccination']
        thisOnce = pd.to_numeric(thisOnce.replace(',','.'))
        curOnce.append(thisOnce)
        
        thisBoth = curRow[curW+'_Anden vaccination']
        thisBoth = pd.to_numeric(thisBoth.replace(',','.'))
        curBoth.append(thisBoth)
        
        thisFull = curRow[curW+'_Fuld vaccineeffekt']
        thisFull = pd.to_numeric(thisFull.replace(',','.'))
        curFull.append(thisFull)
    
    # Add to dataframe
    incidf[curAge+'_Ingen vaccination'] = curNone
    incidf[curAge+'_Første vaccination'] = curOnce
    incidf[curAge+'_Anden vaccination'] = curBoth 
    incidf[curAge+'_Fuld vaccineeffekt'] = curFull
    
    # Add to smaller dataframes as well
    incidf_none[curAge] = curNone
    incidf_once[curAge] = curOnce
    incidf_both[curAge] = curBoth 
    incidf_full[curAge] = curFull
    

# df2_H
# curRow
incidf
# cur
# Out:
#    Ugenummer  12-15_Ingen vaccination  12-15_Første vaccination  \
# 0     Uge 45                   1468.5                     874.5
# 1     Uge 44                    976.3                     521.2
# 2     Uge 43                    754.7                     213.0
# 3     Uge 42                    541.9                     222.2
# 4     Uge 41                    325.5                      78.9
# 5     Uge 40                    311.0                      86.3
# 6     Uge 39                    221.9                      89.3
# 7     Uge 38                    227.4                      70.9
# 8     Uge 37                    189.8                      44.1
# 9     Uge 36                    223.9                      75.4
# 10    Uge 35                    378.1                     126.5
# 11    Uge 34                    511.3                     149.8
# 12    Uge 33                    547.8                     142.0
# 13    Uge 32                    388.2                     141.8
# ...

# %%
for curAge in incidf_none.columns[1:]:

    fig,ax1 = plt.subplots()

    # curAge = '20-29'
    ax1.plot(allDates,incidf_none[curAge],'r',label='Uvaccinerede')
    ax1.plot(allDates,incidf_once[curAge],color='xkcd:light blue',label='Første dosis')
    # ax1.plot(allDates,incidf_both[curAge])
    ax1.plot(allDates,incidf_full[curAge],color='xkcd:dark blue',label='Anden dosis (og fuld vaccineeffekt)')
 
    ax1.set_ylim(bottom=0)
    ax1.set_xlim([allDates.min(),allDates.max()])
    ax1.legend()
    ax1.set_title('Incidens, tilfælde, '+curAge)

    # ax1.set_xlabel('Dato')
    ax1.set_ylabel('Incidens per 100.000')
    
    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d. %b'))
    
    plt.tight_layout()
    
    if saveFigures:
        plt.savefig('figs/gennembrud/inci'+curAge)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ...

# %%
# Flip dataframe to be like df1
inciHospdf = pd.DataFrame()
inciHospdf_once = pd.DataFrame()
inciHospdf_both = pd.DataFrame()
inciHospdf_full = pd.DataFrame()
inciHospdf_none = pd.DataFrame()

weekNames = df1.Ugenummer
inciHospdf['Ugenummer'] = weekNames
inciHospdf_none['Ugenummer'] = weekNames
inciHospdf_once['Ugenummer'] = weekNames
inciHospdf_both['Ugenummer'] = weekNames
inciHospdf_full['Ugenummer'] = weekNames

for k in range(0,len(df3_H)):
    curRow = df3_H.loc[k]
    curAge = df3_H.loc[k,'Aldersgruppe']
    
    curNone = []
    curOnce = []
    curBoth = []
    curFull = []
    for curW in weekNames:
        # print(curW)
        
        thisNone = curRow[curW+'_Ingen vaccination']
        thisNone = pd.to_numeric(thisNone.replace(',','.'))
        curNone.append(thisNone)
        
        thisOnce = curRow[curW+'_Første vaccination']
        thisOnce = pd.to_numeric(thisOnce.replace(',','.'))
        curOnce.append(thisOnce)
        
        thisBoth = curRow[curW+'_Anden vaccination']
        thisBoth = pd.to_numeric(thisBoth.replace(',','.'))
        curBoth.append(thisBoth)
        
        thisFull = curRow[curW+'_Fuld vaccineeffekt']
        thisFull = pd.to_numeric(thisFull.replace(',','.'))
        curFull.append(thisFull)
    
    # Add to dataframe
    inciHospdf[curAge+'_Ingen vaccination'] = curNone
    inciHospdf[curAge+'_Første vaccination'] = curOnce
    inciHospdf[curAge+'_Anden vaccination'] = curBoth 
    inciHospdf[curAge+'_Fuld vaccineeffekt'] = curFull
    
    # Add to smaller dataframes as well
    inciHospdf_none[curAge] = curNone
    inciHospdf_once[curAge] = curOnce
    inciHospdf_both[curAge] = curBoth 
    inciHospdf_full[curAge] = curFull
    

# df2_H
# curRow
inciHospdf
# cur
# Out:
#    Ugenummer  12-15_Ingen vaccination  12-15_Første vaccination  \
# 0     Uge 45                      4.8                       0.0
# 1     Uge 44                      4.6                       0.0
# 2     Uge 43                      4.4                       0.0
# 3     Uge 42                      1.4                       0.0
# 4     Uge 41                      0.0                       0.0
# 5     Uge 40                      2.8                       0.0
# 6     Uge 39                      0.0                       0.0
# 7     Uge 38                      0.0                       0.0
# 8     Uge 37                      0.0                       0.0
# 9     Uge 36                      1.2                       0.0
# 10    Uge 35                      4.6                       0.0
# 11    Uge 34                      3.1                       1.2
# 12    Uge 33                      1.9                       0.0
# 13    Uge 32                      3.2                       0.8
# ...

# %%
for curAge in inciHospdf_none.columns[1:]:

    fig,ax1 = plt.subplots()

    # curAge = '20-29'
    ax1.plot(allDates,inciHospdf_none[curAge],'r',label='Uvaccinerede')
    ax1.plot(allDates,inciHospdf_once[curAge],color='xkcd:light blue',label='Første dosis')
    # ax1.plot(allDates,inciHospdf_both[curAge])
    ax1.plot(allDates,inciHospdf_full[curAge],color='xkcd:dark blue',label='Anden dosis (og fuld vaccineeffekt)')
 
    ax1.set_ylim(bottom=0)
    ax1.set_xlim([allDates.min(),allDates.max()])
    ax1.legend()
    ax1.set_title('Incidens, indlæggelser, '+curAge)

    # ax1.set_xlabel('Dato')
    ax1.set_ylabel('Incidens per 100.000')
    
    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d. %b'))
    
    plt.tight_layout()
    
    if saveFigures:
        plt.savefig('figs/gennembrud/inciHosp'+curAge)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ...

# %%
fig,ax1 = plt.subplots()
ax1.plot(allDates,inciHospdf_full[curAge],'b')
ax1.plot(allDates,inciHospdf_none[curAge],'r')

ax1.set_ylim(bottom=0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (0.0, 26.099999999999998)

# %%
# hospdf_full.sum()
# hospdf_none.sum()
# hospdf_none
curAge = '80+'
curAge = '30-39' 


fig,ax1 = plt.subplots()


for curAge in inciHospdf_none.columns[1:]:
    curRate = inciHospdf_full[curAge] / inciHospdf_none[curAge]

    vaccEff = 1-curRate

    # ax1.plot(allDates,curRate,'*k:')
    # ax1.plot(allDates,100*vaccEff,'*:',label=curAge)
    ax1.plot(rnTime(allDates,4),rnMean(100*vaccEff,4),'*:',label=curAge)

ax1.set_ylim(bottom=0,top=100)
ax1.legend()

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
hospdf_none.sum()
# Out:
# Ugenummer    Uge 45Uge 44Uge 43Uge 42Uge 41Uge 40Uge 39Uge ...
# 12-15                                                       28
# 16-19                                                       30
# 20-29                                                      270
# 30-39                                                      335
# 40-49                                                      255
# 50-59                                                      185
# 60-64                                                       78
# 65-69                                                       44
# 70-79                                                       78
# 80+                                                         67
# 12+                                                       1370
# dtype: object

# %%
hospdf_full.sum()
# Out:
# Ugenummer    Uge 45Uge 44Uge 43Uge 42Uge 41Uge 40Uge 39Uge ...
# 12-15                                                        1
# 16-19                                                       12
# 20-29                                                       34
# 30-39                                                       47
# 40-49                                                       99
# 50-59                                                      132
# 60-64                                                       82
# 65-69                                                      123
# 70-79                                                      429
# 80+                                                        435
# 12+                                                       1394
# dtype: object

# %%
hospdf_full
# Out:
#    Ugenummer  12-15  16-19  20-29  30-39  40-49  50-59  60-64  65-69  70-79  \
# 0     Uge 45      0      3      5      8     18     28     14     28     98
# 1     Uge 44      0      1      6      8     10     22     18     15     63
# 2     Uge 43      0      3      4      9     13     16     10     16     63
# 3     Uge 42      0      1      1      7     11     10      6     13     35
# 4     Uge 41      0      1      1      3      8      9      2      8     32
# 5     Uge 40      0      1      4      1      3      4      2      7     10
# 6     Uge 39      1      0      1      2      1      4      3      4     15
# 7     Uge 38      0      0      3      0      1      3      4      2     17
# 8     Uge 37      0      0      2      1      3      1      4      3     11
# 9     Uge 36      0      0      2      1      5      8      3      5     14
# 10    Uge 35      0      0      2      1      3      5      3      2     12
# ...

# %%
countNone = hospdf_none.iloc[:,1:-1].sum().values
countFull = hospdf_full.iloc[:,1:-1].sum().values
ageGroups = hospdf_full.columns[1:-1]

fig,(ax1,ax2) = plt.subplots(2,1)

allCount = countNone + countFull
ax1.bar(ageGroups,allCount,color='xkcd:blue',label='Vaccinated')
ax1.bar(ageGroups,countNone,color='xkcd:light red',label='Unvaccinated')

ax2.bar(ageGroups,100*np.divide(allCount,allCount),color='xkcd:blue',label='Vaccinated')
ax2.bar(ageGroups,100*np.divide(countNone,allCount),color='xkcd:light red',label='Unvaccinated')

ax1.legend()

ax2.set_ylim([0,100])

ax1.set_ylabel('Number of hospitalizations')
ax2.set_ylabel('Ratio of hospitalizations [%]')
ax2.set_xlabel('Age group')

plt.savefig('figs/gennembrud/Hospitaliseringer')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
firstIndex = 0
lastIndex = 4
countNoneRec = hospdf_none.iloc[firstIndex:lastIndex,1:-1].sum().values
countFullRec = hospdf_full.iloc[firstIndex:lastIndex,1:-1].sum().values
allCountRec = countNoneRec + countFullRec

fig,(ax1,ax2) = plt.subplots(2,1)

ax1.bar(ageGroups,allCountRec,color='xkcd:blue',label='Vaccinated')
ax1.bar(ageGroups,countNoneRec,color='xkcd:light red',label='Unvaccinated')

ax2.bar(ageGroups,100*np.divide(allCountRec,allCountRec),color='xkcd:blue',label='Vaccinated')
ax2.bar(ageGroups,100*np.divide(countNoneRec,allCountRec),color='xkcd:light red',label='Unvaccinated')

ax1.legend()

ax2.set_ylim([0,100])

ax1.set_ylabel('Antal indlæggelser')
ax2.set_ylabel('Andel af indlæggelser [%]')
ax2.set_xlabel('Aldersgruppe')

titleText = f'I perioden {allDates[lastIndex]:%d. %b} til {allDates[firstIndex]:%d. %b} '
ax1.set_title(titleText)

plt.savefig('figs/gennembrud/HospitaliseringerNylig')

ax1.set_ylabel('Number of hospitalizations')
ax2.set_ylabel('Ratio of hospitalizations [%]')
ax2.set_xlabel('Age group')
titleText = f'Between {allDates[lastIndex]:%d. %b} and {allDates[firstIndex]:%d. %b} '
ax1.set_title(titleText)

plt.savefig('figs/gennembrud/HospitalizationsRecent')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
countNoneInci = inciHospdf_none.iloc[:,1:-1].sum().values
countFullInci = inciHospdf_full.iloc[:,1:-1].sum().values
ageGroups = inciHospdf_full.columns[1:-1]

fig,ax1 = plt.subplots()

allCount = countNoneInci + countFullInci
# ax1.bar(ageGroups,countFullInci,color='xkcd:blue',label='Vaccinated')
# ax1.bar(ageGroups,countNoneInci,color='xkcd:light red',label='Unvaccinated')
ax1.bar(np.arange(0,len(ageGroups))-0.15,countFullInci,width=0.3,color='xkcd:blue',label='Vaccinated')
ax1.bar(np.arange(0,len(ageGroups))+0.15,countNoneInci,width=0.3,color='xkcd:light red',label='Unvaccinated')

# ax2.bar(ageGroups,100*np.divide(allCount,allCount),color='xkcd:blue',label='Vaccinated')
# ax2.bar(ageGroups,100*np.divide(countNoneInci,allCount),color='xkcd:light red',label='Unvaccinated')

ax1.set_xticks(np.arange(0,len(ageGroups)))
ax1.set_xticklabels(ageGroups)

ax1.legend()

# ax2.set_ylim([0,100])

ax1.set_ylabel('Hospitalization incidence per 100,000')
ax1.set_xlabel('Age group')
# ax2.set_ylabel('Ratio of hospitalizations [%]')
# ax2.set_xlabel('Age group')

plt.savefig('figs/gennembrud/HospitaliseringerIncidens')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
countNoneInciRec = inciHospdf_none.iloc[firstIndex:lastIndex,1:-1].sum().values
countFullInciRec = inciHospdf_full.iloc[firstIndex:lastIndex,1:-1].sum().values
# allCountRec = countNoneInciRec + countFullInciRec

fig,ax1 = plt.subplots()

ax1.bar(np.arange(0,len(ageGroups))-0.15,countFullInciRec,width=0.3,color='xkcd:blue',label='Vaccinated')
ax1.bar(np.arange(0,len(ageGroups))+0.15,countNoneInciRec,width=0.3,color='xkcd:light red',label='Unvaccinated')

ax1.set_xticks(np.arange(0,len(ageGroups)))
ax1.set_xticklabels(ageGroups)

ax1.legend()


ax1.set_ylabel('Indlæggelses incidens per 100.000')
ax1.set_xlabel('Aldersgruppe')
titleText = f'I perioden {allDates[lastIndex]:%d. %b} til {allDates[firstIndex]:%d. %b} '
ax1.set_title(titleText)

plt.savefig('figs/gennembrud/HospitaliseringerIncidensNylig')


ax1.set_ylabel('Hospitalization incidence per 100,000')
ax1.set_xlabel('Age group')
titleText = f'Between {allDates[lastIndex]:%d. %b} and {allDates[firstIndex]:%d. %b} '
ax1.set_title(titleText)

plt.savefig('figs/gennembrud/HospitalizationsIncidenceRecent')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig,ax1 = plt.subplots()

# allCount = countNone + countFull
# # ax1.bar(ageGroups,countFull,color='xkcd:blue',label='Vaccinated')
# # ax1.bar(ageGroups,countNone,color='xkcd:light red',label='Unvaccinated')
# ax1.bar(np.arange(0,len(ageGroups))-0.15,countFull,width=0.3,color='xkcd:blue',label='Vaccinated')
# ax1.bar(np.arange(0,len(ageGroups))+0.15,countNone,width=0.3,color='xkcd:light red',label='Unvaccinated')

ax1.bar(ageGroups,100*(countNoneInci - countFullInci)/(countNoneInci),color='k')
# ax1.bar(ageGroups,100 - 100*(countNone - countFull)/(countNone))

ax1.set_ylim([0,100])
ax1.set_ylabel('Vaccine effectiveness\nin regards to hospitalization [%]')

plt.savefig('figs/gennembrud/VaccineEffect')


fig,ax1 = plt.subplots()


ax1.bar(ageGroups,100 - 100*(countNoneInci - countFullInci)/(countNoneInci),color='k')
# ax1.bar(ageGroups,100 - 100*(countNone - countFull)/(countNone))

# ax1.set_ylim([0,20])
ax1.set_ylabel('Risk of breakthrough-hospitalization [%]')

plt.savefig('figs/gennembrud/VaccineEffectInverse')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# The same, but recent

fig,ax1 = plt.subplots()

ax1.bar(ageGroups,100*(countNoneInciRec - countFullInciRec)/(countNoneInciRec),color='k')
# ax1.bar(ageGroups,100 - 100*(countNone - countFull)/(countNone))

ax1.set_ylim([0,100])
ax1.set_ylabel('Vaccine effectiveness\nin regards to hospitalization [%]')

titleText = f'Between {allDates[lastIndex]:%d. %b} and {allDates[firstIndex]:%d. %b} '
ax1.set_title(titleText)

plt.savefig('figs/gennembrud/VaccineEffectRecent')


fig,ax1 = plt.subplots()


ax1.bar(ageGroups,100 - 100*(countNoneInciRec - countFullInciRec)/(countNoneInciRec),color='k')
# ax1.bar(ageGroups,100 - 100*(countNone - countFull)/(countNone))

# ax1.set_ylim([0,20])
ax1.set_ylabel('Risk of breakthrough-hospitalization [%]')
titleText = f'Between {allDates[lastIndex]:%d. %b} and {allDates[firstIndex]:%d. %b} '
ax1.set_title(titleText)

plt.savefig('figs/gennembrud/VaccineEffectInverseRecent')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# The same, but recent

firstIndex = 0
lastIndex = 4
countNoneInciRec = inciHospdf_none.iloc[firstIndex:lastIndex,1:-1].sum().values
countFullInciRec = inciHospdf_full.iloc[firstIndex:lastIndex,1:-1].sum().values

fig,ax1 = plt.subplots()

ax1.bar(ageGroups,countNoneInciRec/countFullInciRec,color='k')

# ax1.set_ylim([0,100])
ax1.set_ylabel('Relative risk')

titleText = f'Between {allDates[lastIndex]:%d. %b} and {allDates[firstIndex]:%d. %b} '
ax1.set_title(titleText)

# plt.savefig('figs/gennembrud/VaccineEffectRecent')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <ipython-input-36-ba8c8685b6b1>:10: RuntimeWarning: divide by zero encountered in true_divide
#   ax1.bar(ageGroups,countNoneInciRec/countFullInciRec,color='k')
# Text(0.5, 1.0, 'Between 12. okt and 09. nov ')

# %%
# inciHospdf_none.iloc[firstIndex:lastIndex,firstAgeIndex:-1]
# # ageGroups[firstAgeIndex-1][0:2]

# countNoneInciRec = inciHospdf_none.iloc[firstIndex:lastIndex,1:-1].sum().values
# countNoneInciRec

# countNoneInciRecAll = inciHospdf_none.iloc[firstIndex:lastIndex,firstAgeIndex:-1].sum().sum()
# countNoneInciRec = np.append(countNoneInciRec,countNoneInciRecAll)

# countNoneInciRec

# %%
firstIndex = 0
lastIndex = 4
# countNoneRec = hospdf_none.iloc[firstIndex:lastIndex,1:-1].sum().values
# countFullRec = hospdf_full.iloc[firstIndex:lastIndex,1:-1].sum().values
# allCountRec = countNoneRec + countFullRec
# hospdf_none.iloc[firstIndex:lastIndex,1:].sum().values

countNoneInciRec = inciHospdf_none.iloc[firstIndex:lastIndex,1:-1].sum().values
countFullInciRec = inciHospdf_full.iloc[firstIndex:lastIndex,1:-1].sum().values
# ageGroupsAll = inciHospdf_none.columns[1:]

firstAgeIndex = 3
countNoneInciRecAll = inciHospdf_none.iloc[firstIndex:lastIndex,firstAgeIndex:-1].sum().sum()
countFullInciRecAll = inciHospdf_full.iloc[firstIndex:lastIndex,firstAgeIndex:-1].sum().sum()
# countNoneInciRecAll
# countFullInciRecAll

countNoneInciRec = np.append(countNoneInciRec,countNoneInciRecAll)
countFullInciRec = np.append(countFullInciRec,countFullInciRecAll)
ageGroupsAll = np.append(ageGroups,ageGroups[firstAgeIndex-1][0:2]+'+')
ageGroupsAll

# Cut off some stuff
ageGroupsAll = ageGroupsAll[firstAgeIndex-1:]
countNoneInciRec = countNoneInciRec[firstAgeIndex-1:]
countFullInciRec = countFullInciRec[firstAgeIndex-1:]
 
fig,ax1 = plt.subplots()
valsToShow = 100*(countNoneInciRec - countFullInciRec)/(countNoneInciRec)
ax1.bar(ageGroupsAll,valsToShow,color='k')

for k in range(len(valsToShow)):
    ax1.text(k,valsToShow[k]-2,f'{valsToShow[k]:2.0f} %',fontsize=15,color='white',ha='center',va='top')
    
# ax1.bar(ageGroupsAll,100 - 100*(countNone - countFull)/(countNone))

ax1.set_ylim([0,100])
ax1.set_ylabel('Vaccine effectiveness\nin regards to hospitalization [%]')

titleText = f'Between {allDates[lastIndex]:%d. %b} and {allDates[firstIndex]:%d. %b} '
# ax1.set_yticks(np.arange(0,101,20))
ax1.set_title(titleText)
# ax1.grid(axis='y')

plt.savefig('figs/gennembrud/VaccineEffectRecentWithSum')


# fig,ax1 = plt.subplots()


# ax1.bar(ageGroupsAll,100 - 100*(countNoneInciRec - countFullInciRec)/(countNoneInciRec),color='k')
# # ax1.bar(ageGroupsAll,100 - 100*(countNone - countFull)/(countNone))

# # ax1.set_ylim([0,20])
# ax1.set_ylabel('Risk of breakthrough-hospitalization [%]')
# titleText = f'Between {allDates[lastIndex]:%d. %b} and {allDates[firstIndex]:%d. %b} '
# ax1.set_title(titleText)

# # plt.savefig('figs/gennembrud/VaccineEffectInverseRecent')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
100*(countNoneInciRec - countFullInciRec)/(countNoneInciRec)
# Out:
# array([94.27480916, 92.12792128, 92.2005571 , 91.24797407, 91.62534435,
#        82.96973962, 78.69662921, 71.06552358, 83.03838384])

# %%
# df2_H
# # 0.6 * (500000/ 100000 )

# # ((3) /(700000*0.77)) * 100000
# # inciHospdf_none
# incidf_none
# casedf_none

# print(countFullInciRec)
# print(countNoneInciRec)
# # df2_H
# hospdf_none


firstIndex = 0
lastIndex = 4
countNoneInciRec = inciHospdf_none.iloc[firstIndex:lastIndex,1:-1].sum().values
countFullInciRec = inciHospdf_full.iloc[firstIndex:lastIndex,1:-1].sum().values
countNoneRec = hospdf_none.iloc[firstIndex:lastIndex,1:-1].sum().values
countFullRec = hospdf_full.iloc[firstIndex:lastIndex,1:-1].sum().values
# allCountRec = countNoneRec + countFullRec

errNone = np.sqrt(countNoneRec)
errFull = np.sqrt(countFullRec)

relErrNone = errNone/countNoneRec
relErrFull = errFull/countFullRec

D = 1- (countFullInciRec/countNoneInciRec)

X = countFullInciRec
Y = countNoneInciRec
dX = relErrFull * X 
dY = relErrNone * Y
# dD = np.sqrt((dX/X)^2 + (dY/Y)^2)*D
dD = np.sqrt(np.power(relErrFull,2) + np.power(relErrNone,2)) * D
dD
# Out:
# <ipython-input-40-acceffe5759d>:27: RuntimeWarning: invalid value encountered in true_divide
#   relErrFull = errFull/countFullRec
# array([       nan, 0.43090031, 0.2581822 , 0.18582447, 0.16423807,
#        0.15480695, 0.21324638, 0.2237299 , 0.13998001, 0.1394094 ])

# %%
# countNoneInciRec
# errNone
# countNoneRec
fig,(ax1,ax2) = plt.subplots(2,1)
ax1.errorbar(ageGroups,countNoneRec,capsize=5,linewidth=2,yerr=errNone,label='Uvaccinerede')
ax1.errorbar(ageGroups,countFullRec,capsize=5,linewidth=2,yerr=errFull,label='Vaccinerede')
ax1.legend()
ax1.set_ylabel('Antal indlæggelser')
ax2.errorbar(ageGroups,countNoneInciRec,capsize=5,linewidth=2,yerr=errNone,label='Uvaccinerede')
ax2.errorbar(ageGroups,countFullInciRec,capsize=5,linewidth=2,yerr=errFull,label='Vaccinerede')
ax2.legend()
ax2.set_ylabel('Indlæggelsesincidens')

ax1.set_ylim(bottom=0)
ax2.set_ylim(bottom=0)

titleText = f'Mellem {allDates[lastIndex]:%d. %b} og {allDates[firstIndex]:%d. %b} '
ax1.set_title(titleText)

plt.tight_layout()

plt.savefig('figs/gennembrud/AldersfordelingRecent')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig,ax1 = plt.subplots()
# plt.plot(ageGroups,D) 
# plt.plot(ageGroups,D+dD) 
# plt.plot(ageGroups,D-dD) 

ax1.errorbar(ageGroups,D,yerr=1*dD,fmt='bs',capsize=4,elinewidth=1)
ax1.plot(ageGroups,1-(2*countFullInciRec/countNoneInciRec),'k.')
# ax1.errorbar(ageGroups,D,yerr=2*dD,fmt='b.',capsize=6,elinewidth=1)

ax1.set_ylim([0,1])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (0.0, 1.0)

# %%
fig,ax1 = plt.subplots()

ax1.errorbar(ageGroups,countNoneInciRec,yerr=2*relErrNone*countNoneInciRec,fmt='k.',capsize=4,elinewidth=1,label='Unvaccinated')
ax1.errorbar(ageGroups,countFullInciRec,yerr=2*relErrFull*countFullInciRec,fmt='b.',capsize=4,elinewidth=1,label='Vaccinated')

ax1.set_ylim(bottom=0)
ax1.legend()
ax1.set_ylabel('Hospitalizations, incidence per 100,000')
titleText = f'Between {allDates[lastIndex]:%d. %b} and {allDates[firstIndex]:%d. %b} '
ax1.set_title(titleText)

plt.tight_layout()

plt.savefig('figs/gennembrud/HospInci_WithErrorbars_Recent')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print('Fuld vaccinerede')
display(inciHospdf_full)
print('Sum for de sidste fire uger:')
display(inciHospdf_full.iloc[0:4,1:].sum())
print('Uvaccinerede')
display(inciHospdf_none)
print('Sum for de sidste fire uger:')
display(inciHospdf_none.iloc[0:4,1:].sum())
# Out:
# Fuld vaccinerede
#    Ugenummer  12-15  16-19  20-29  30-39  40-49  50-59  60-64  65-69  70-79  \
# 0     Uge 45    0.0    1.4    0.9    1.6    2.9    4.0    4.4    9.4   18.0
# 1     Uge 44    0.0    0.5    1.1    1.6    1.6    3.1    5.7    5.0   11.5
# 2     Uge 43    0.0    1.4    0.8    1.8    2.1    2.3    3.2    5.4   11.5
# 3     Uge 42    0.0    0.5    0.2    1.4    1.8    1.4    1.9    4.4    6.4
# 4     Uge 41    0.0    0.5    0.2    0.6    1.3    1.3    0.6    2.7    5.9
# 5     Uge 40    0.0    0.5    0.8    0.2    0.5    0.6    0.6    2.3    1.8
# 6     Uge 39    0.7    0.0    0.2    0.4    0.2    0.6    0.9    1.3    2.7
# 7     Uge 38    0.0    0.0    0.6    0.0    0.2    0.4    1.3    0.7    3.1
# 8     Uge 37    0.0    0.0    0.4    0.2    0.5    0.1    1.3    1.0    2.0
# 9     Uge 36    0.0    0.0    0.4    0.2    0.8    1.1    1.0    1.7    2.6
# 10    Uge 35    0.0    0.0    0.5    0.3    0.5    0.7    1.0    0.7    2.2
# ...

# %%
print('Fuld vaccinerede')
display(hospdf_full)
print('Sum for de sidste fire uger:')
display(hospdf_full.iloc[0:4,1:].sum())
print('Uvaccinerede')
display(hospdf_none)
print('Sum for de sidste fire uger:')
display(hospdf_none.iloc[0:4,1:].sum())
# Out:
# Fuld vaccinerede
#    Ugenummer  12-15  16-19  20-29  30-39  40-49  50-59  60-64  65-69  70-79  \
# 0     Uge 45      0      3      5      8     18     28     14     28     98
# 1     Uge 44      0      1      6      8     10     22     18     15     63
# 2     Uge 43      0      3      4      9     13     16     10     16     63
# 3     Uge 42      0      1      1      7     11     10      6     13     35
# 4     Uge 41      0      1      1      3      8      9      2      8     32
# 5     Uge 40      0      1      4      1      3      4      2      7     10
# 6     Uge 39      1      0      1      2      1      4      3      4     15
# 7     Uge 38      0      0      3      0      1      3      4      2     17
# 8     Uge 37      0      0      2      1      3      1      4      3     11
# 9     Uge 36      0      0      2      1      5      8      3      5     14
# 10    Uge 35      0      0      2      1      3      5      3      2     12
# ...

# %%
print(hospdf_full.iloc[0:4,3:8].sum().sum())
print(hospdf_both.iloc[0:4,3:8].sum().sum())
print(hospdf_once.iloc[0:4,3:8].sum().sum())
print(hospdf_none.iloc[0:4,3:8].sum().sum())
display(hospdf_none.iloc[0:4,3:8])

print(114/(114+197+11+1))
print(1/(114+197+11+1))
print(11/(114+197+11+1))
print(197/(114+197+11+1))


print((115+11)/(114+197+11+1))
print(197/(114+197+11+1))
# Out:
# 224
# 226
# 23
# 360
#    20-29  30-39  40-49  50-59  60-64
# 0     20     30     22     18      9
# 1     23     36     24     23      6
# 2     19     23     18     14      9
# 3     18     17     16      9      6
# 0.35294117647058826
# 0.0030959752321981426
# 0.034055727554179564
# 0.6099071207430341
# 0.39009287925696595
# 0.6099071207430341

# %%
print(hospdf_full.iloc[0:4,3:7].sum().sum())
print(hospdf_both.iloc[0:4,3:7].sum().sum())
print(hospdf_once.iloc[0:4,3:7].sum().sum())
print(hospdf_none.iloc[0:4,3:7].sum().sum())
display(hospdf_none.iloc[0:4,3:7])

print(70/(70+177+10+1))
print(1/(70+177+10+1))
print(10/(70+177+10+1))
print(177/(70+177+10+1))


print((71+10)/(70+177+10+1))
print(177/(70+177+10+1))
# Out:
# 176
# 178
# 22
# 330
#    20-29  30-39  40-49  50-59
# 0     20     30     22     18
# 1     23     36     24     23
# 2     19     23     18     14
# 3     18     17     16      9
# 0.2713178294573643
# 0.003875968992248062
# 0.03875968992248062
# 0.686046511627907
# 0.313953488372093
# 0.686046511627907

# %%
print(casedf_full.iloc[0:4,3:7].sum().sum())
print(casedf_both.iloc[0:4,3:7].sum().sum())
print(casedf_once.iloc[0:4,3:7].sum().sum())
print(casedf_none.iloc[0:4,3:7].sum().sum())
display(casedf_none.iloc[0:4,3:7])

# print(70/(70+177+10+1))
# print(1/(70+177+10+1))
# print(10/(70+177+10+1))
# print(177/(70+177+10+1))


print((6573+296)/(6573+296+4095))
print((4095)/(6573+296+4095))

print((6573+296))
# Out:
# 20637
# 20706
# 715
# 9445
#    20-29  30-39  40-49  50-59
# 0   1125   1027    682    338
# 1    901    821    492    225
# 2    885    673    413    207
# 3    630    590    307    129
# 0.6265049252097774
# 0.37349507479022254
# 6869

# %%
print(inciHospdf_full.iloc[0:4,3:8].sum().sum())
print(inciHospdf_both.iloc[0:4,3:8].sum().sum())
print(inciHospdf_once.iloc[0:4,3:8].sum().sum())
print(inciHospdf_none.iloc[0:4,3:8].sum().sum())
inciHospdf_none.iloc[0:4,3:8]
# Out:
# 43.800000000000004
# 44.0
# 379.8
# 546.3
#    20-29  30-39  40-49  50-59  60-64
# 0   13.4   23.5   30.1   35.1   55.1
# 1   15.1   27.7   32.4   44.4   36.4
# 2   12.3   17.4   24.0   26.8   54.1
# 3   11.6   12.7   21.2   17.1   35.9

# %%
dfPop = pd.read_excel('DKfolketal2021clean.xlsx')
dfPop[20:29].Antal.sum()
# Out:
# 700466

# %%
# inciHospdf_none
print(hospdf_full.iloc[:,1:-1].sum().sum())
print(hospdf_none.iloc[:,1:-1].sum().sum())
print(hospdf_once.iloc[:,1:-1].sum().sum())
print(hospdf_both.iloc[:,1:-1].sum().sum())

print('Vaccinerede:')
print(hospdf_full.iloc[:,1:-1].sum())


print('\n Uvaccinerede:')
hospdf_none.iloc[:,1:-1].sum()
# Out:
# 1394
# 1370
# 160
# 1414
# Vaccinerede:
# 12-15      1
# 16-19     12
# 20-29     34
# 30-39     47
# 40-49     99
# 50-59    132
# 60-64     82
# 65-69    123
# 70-79    429
# 80+      435
# dtype: int64
#
#  Uvaccinerede:
# 12-15     28
# 16-19     30
# 20-29    270
# 30-39    335
# 40-49    255
# 50-59    185
# 60-64     78
# 65-69     44
# 70-79     78
# 80+       67
# dtype: int64

# %%
countFull = hospdf_full.iloc[:,1:-1].sum()
countNone = hospdf_none.iloc[:,1:-1].sum()
print(100 * countNone / (countNone+countFull))
print(100 * countFull / (countNone+countFull))
(countNone+countFull)
# Out:
# 12-15    96.551724
# 16-19    71.428571
# 20-29    88.815789
# 30-39    87.696335
# 40-49    72.033898
# 50-59    58.359621
# 60-64    48.750000
# 65-69    26.347305
# 70-79    15.384615
# 80+      13.346614
# dtype: float64
# 12-15     3.448276
# 16-19    28.571429
# 20-29    11.184211
# 30-39    12.303665
# 40-49    27.966102
# 50-59    41.640379
# 60-64    51.250000
# 65-69    73.652695
# 70-79    84.615385
# 80+      86.653386
# dtype: float64
# 12-15     29
# 16-19     42
# 20-29    304
# 30-39    382
# 40-49    354
# 50-59    317
# 60-64    160
# 65-69    167
# 70-79    507
# 80+      502
# dtype: int64

# %%
# display(hospdf_none)
# incihospdf_none
# ho
# display(hospdf_full)

# %%
# inciHospdf_none
# display(hospdf_none)
# display(hospdf_full)

# %%
fig,ax1 = plt.subplots()

ax1.plot(allDates,hospdf_none['12+'],label='Uvaccinerede')
ax1.plot(allDates,hospdf_full['12+'],label='Vaccinerede')

ax1.legend()
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d. %b'))

ax1.set_ylabel('Indlæggelser (antal)')

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig,ax1 = plt.subplots()

ax1.plot(allDates,casedf_none['12+'],label='Uvaccinerede')
ax1.plot(allDates,casedf_full['12+'],label='Vaccinerede')

ax1.legend()
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d. %b'))

ax1.set_ylabel('Tilfælde (antal)')

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Stacked figur?

# %%
curCount = np.zeros(casedf_full['12-15'].shape)
preCount = np.zeros(casedf_full['12-15'].shape)
curHosp = np.zeros(casedf_full['12-15'].shape)
preHosp = np.zeros(casedf_full['12-15'].shape)

# ageGroups

# fig,ax1 = plt.subplots()
fig,(ax1,ax2) = plt.subplots(2,1,sharex=True)

for curAge in ageGroups:
    thisCount = casedf_full[curAge].values
    thisHosp = hospdf_full[curAge].values
    
    curCount = curCount + thisCount
    curHosp = curHosp + thisHosp
    # ax1.plot(allDates,curCount)
    ax1.fill_between(allDates,curCount,preCount,label=curAge)
    preCount = preCount + thisCount
    ax2.fill_between(allDates,curHosp,preHosp,label=curAge)
    preHosp = preHosp + thisHosp
    
ax1.legend(loc='upper left')
ax1.set_ylabel('Tilfælde (antal)')
ax2.set_ylabel('Indlæggelser (antal)')

ax1.set_ylim(bottom=0)
ax2.set_ylim(bottom=0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (0.0, 301.35)

# %%
curCount = np.zeros(casedf_none['12-15'].shape)
preCount = np.zeros(casedf_none['12-15'].shape)
curHosp = np.zeros(casedf_none['12-15'].shape)
preHosp = np.zeros(casedf_none['12-15'].shape)

# ageGroups

# fig,ax1 = plt.subplots()
fig,(ax1,ax2) = plt.subplots(2,1,sharex=True)

for curAge in ageGroups:
    thisCount = casedf_none[curAge].values
    thisHosp = hospdf_none[curAge].values
    
    curCount = curCount + thisCount
    curHosp = curHosp + thisHosp
    # ax1.plot(allDates,curCount)
    ax1.fill_between(allDates,curCount,preCount,label=curAge)
    preCount = preCount + thisCount
    ax2.fill_between(allDates,curHosp,preHosp,label=curAge)
    preHosp = preHosp + thisHosp
    
ax1.legend(loc='upper left')
ax1.set_ylabel('Tilfælde (antal)')
ax2.set_ylabel('Indlæggelser (antal)')

ax1.set_title('Uvaccinerede')
ax1.set_ylim(bottom=0)
ax2.set_ylim(bottom=0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (0.0, 145.95)

# %%
curCount = np.zeros(casedf_none['12-15'].shape)
preCount = np.zeros(casedf_none['12-15'].shape)
curHosp = np.zeros(casedf_none['12-15'].shape)
preHosp = np.zeros(casedf_none['12-15'].shape)

# ageGroups

# fig,ax1 = plt.subplots()
fig,(ax1,ax2) = plt.subplots(2,1,sharex=True)

for curAge in ageGroups:
    thisCount = casedf_none[curAge].values
    thisHosp = casedf_full[curAge].values
    
    curCount = curCount + thisCount
    curHosp = curHosp + thisHosp
    # ax1.plot(allDates,curCount)
    ax1.fill_between(allDates,curCount,preCount,label=curAge)
    preCount = preCount + thisCount
    ax2.fill_between(allDates,curHosp,preHosp,label=curAge)
    preHosp = preHosp + thisHosp
    
ax1.legend(loc='upper left')
ax1.set_ylabel('Uvaccinerede')
ax2.set_ylabel('Vaccinerede')

ax1.set_title('Tilfælde (antal)')
ax1.set_ylim(bottom=0)
ax2.set_ylim(bottom=0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (0.0, 12232.5)

# %%
curCount = np.zeros(casedf_none['12-15'].shape)
preCount = np.zeros(casedf_none['12-15'].shape)
curHosp = np.zeros(casedf_none['12-15'].shape)
preHosp = np.zeros(casedf_none['12-15'].shape)

# ageGroups

# fig,ax1 = plt.subplots()
fig,(ax1,ax2) = plt.subplots(2,1,sharex=True)

for curAge in ageGroups:
    thisCount = hospdf_none[curAge].values
    thisHosp = hospdf_full[curAge].values
    
    curCount = curCount + thisCount
    curHosp = curHosp + thisHosp
    # ax1.plot(allDates,curCount)
    ax1.fill_between(allDates,curCount,preCount,label=curAge)
    preCount = preCount + thisCount
    ax2.fill_between(allDates,curHosp,preHosp,label=curAge)
    preHosp = preHosp + thisHosp
    
ax1.legend(loc='upper left')
ax1.set_ylabel('Uvaccinerede')
ax2.set_ylabel('Vaccinerede')

ax1.set_title('Indlæggelser (antal)')
ax1.set_ylim(bottom=0)
ax2.set_ylim(bottom=0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (0.0, 301.35)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
