# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important; }</stule>"))
# Out:
# C:\Users\Christian\AppData\Local\Temp\ipykernel_4184\1130998888.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container {width:100% !important; }</stule>

# %%
# %matplotlib widget
# Load packages and settings
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.min_rows', 50)
import seaborn as sns

import csv

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (12,8)
plt.rcParams["image.cmap"] = "tab10"
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.tab10.colors)
fs_label = 16
parameters = {
                'axes.labelsize': fs_label,
                'axes.titlesize': fs_label+4,
                'xtick.labelsize': fs_label,
                'ytick.labelsize': fs_label, 
                'legend.fontsize': fs_label, 
                'lines.markersize': 10,
                'lines.linewidth': 3
             }
plt.rcParams.update(parameters)

from matplotlib import cm # Colormaps
import matplotlib.colors as colors
# cmap = plt.cm.get_cmap('Dark2',len(ageGroups))

import locale
import matplotlib.dates as mdates
locale.setlocale(locale.LC_TIME,"Danish")
# ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b\n%Y'))
# ax1.spines['top'].set_visible(False) 

import os
# import csv
import math

from datetime import date
# import datetime

saveFigures = True
# saveFigures = False
print('saveFigures is set to: '+str(saveFigures))

print('Done loading packages')

# Define running mean functions
def rnMean(data,meanWidth):
    return np.convolve(data, np.ones(meanWidth)/meanWidth, mode='valid')
def rnTime(t,meanWidth):
    return t[math.floor(meanWidth/2):-math.ceil(meanWidth/2)+1]
# Out:
# saveFigures is set to: True
# Done loading packages

# %%
# Read file, manually fixed quotes in given file!
df = pd.read_csv("ECDC_surveillance_data_Respiratory_Syncytial_Virus (non-sentinel numbers).csv",
                delimiter = ',',quoting=csv.QUOTE_NONE)

# %%
df
# Out:
#                        HealthTopic            Population          Indicator  \
# 0     "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 1     "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 2     "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 3     "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 4     "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 5     "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6     "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 7     "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 8     "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 9     "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 10    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 11    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 12    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 13    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 14    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 15    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 16    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 17    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 18    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 19    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 20    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 21    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 22    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 23    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 24    "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# ...                            ...                   ...                ...
# 6185  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6186  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6187  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6188  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6189  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6190  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6191  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6192  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6193  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6194  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6195  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6196  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6197  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6198  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6199  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6200  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6201  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6202  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6203  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6204  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6205  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6206  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6207  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6208  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
# 6209  "Respiratory Syncytial Virus  ""RSV Non sentinel""  ""RSV detection""
#
#        Unit          Time    RegionCode       RegionName  NumValue TxtValue
# 0     ""N""  ""2014-W40""        ""DE""      ""Germany""       0.0    """""
# 1     ""N""  ""2014-W40""        ""DK""      ""Denmark""       0.0    """""
# 2     ""N""  ""2014-W40""        ""EE""      ""Estonia""       1.0    """""
# 3     ""N""  ""2014-W40""        ""EL""       ""Greece""       0.0    """""
# 4     ""N""  ""2014-W40""        ""ES""        ""Spain""       2.0    """""
# 5     ""N""  ""2014-W40""  ""EU31_UKX""       ""EU/EEA""      32.0    """""
# 6     ""N""  ""2014-W40""        ""FI""      ""Finland""       0.0    """""
# 7     ""N""  ""2014-W40""        ""FR""       ""France""       8.0    """""
# 8     ""N""  ""2014-W40""        ""IE""      ""Ireland""       1.0    """""
# 9     ""N""  ""2014-W40""        ""LT""    ""Lithuania""       2.0    """""
# 10    ""N""  ""2014-W40""        ""LV""       ""Latvia""       1.0    """""
# 11    ""N""  ""2014-W40""        ""NL""  ""Netherlands""       3.0    """""
# 12    ""N""  ""2014-W40""        ""PL""       ""Poland""       0.0    """""
# 13    ""N""  ""2014-W40""        ""PT""     ""Portugal""       0.0    """""
# 14    ""N""  ""2014-W40""        ""SE""       ""Sweden""      10.0    """""
# 15    ""N""  ""2014-W40""        ""SI""     ""Slovenia""       4.0    """""
# 16    ""N""  ""2014-W41""        ""DE""      ""Germany""       0.0    """""
# 17    ""N""  ""2014-W41""        ""DK""      ""Denmark""       0.0    """""
# 18    ""N""  ""2014-W41""        ""EE""      ""Estonia""       0.0    """""
# 19    ""N""  ""2014-W41""        ""EL""       ""Greece""       0.0    """""
# 20    ""N""  ""2014-W41""        ""ES""        ""Spain""       0.0    """""
# 21    ""N""  ""2014-W41""  ""EU31_UKX""       ""EU/EEA""      29.0    """""
# 22    ""N""  ""2014-W41""        ""FI""      ""Finland""       0.0    """""
# 23    ""N""  ""2014-W41""        ""FR""       ""France""      15.0    """""
# 24    ""N""  ""2014-W41""        ""IE""      ""Ireland""       5.0    """""
# ...     ...           ...           ...              ...       ...      ...
# 6185  ""N""  ""2022-W04""        ""SE""       ""Sweden""     139.0    """""
# 6186  ""N""  ""2022-W04""        ""SI""     ""Slovenia""      16.0    """""
# 6187  ""N""  ""2022-W04""        ""SK""     ""Slovakia""       0.0    """""
# 6188  ""N""  ""2022-W05""        ""BG""     ""Bulgaria""       1.0    """""
# 6189  ""N""  ""2022-W05""        ""DE""      ""Germany""       0.0    """""
# 6190  ""N""  ""2022-W05""        ""DK""      ""Denmark""       7.0    """""
# 6191  ""N""  ""2022-W05""        ""EE""      ""Estonia""       1.0    """""
# 6192  ""N""  ""2022-W05""        ""EL""       ""Greece""       0.0    """""
# 6193  ""N""  ""2022-W05""        ""ES""        ""Spain""       8.0    """""
# 6194  ""N""  ""2022-W05""  ""EU31_UKX""       ""EU/EEA""     348.0    """""
# 6195  ""N""  ""2022-W05""        ""FI""      ""Finland""       0.0    """""
# 6196  ""N""  ""2022-W05""        ""FR""       ""France""     129.0    """""
# 6197  ""N""  ""2022-W05""        ""HR""      ""Croatia""       0.0    """""
# 6198  ""N""  ""2022-W05""        ""HU""      ""Hungary""       5.0    """""
# 6199  ""N""  ""2022-W05""        ""IE""      ""Ireland""       1.0    """""
# 6200  ""N""  ""2022-W05""        ""IS""      ""Iceland""      13.0    """""
# 6201  ""N""  ""2022-W05""        ""LT""    ""Lithuania""       6.0    """""
# 6202  ""N""  ""2022-W05""        ""LU""   ""Luxembourg""       0.0    """""
# 6203  ""N""  ""2022-W05""        ""LV""       ""Latvia""       4.0    """""
# 6204  ""N""  ""2022-W05""        ""NL""  ""Netherlands""      44.0    """""
# 6205  ""N""  ""2022-W05""        ""PL""       ""Poland""       0.0    """""
# 6206  ""N""  ""2022-W05""        ""PT""     ""Portugal""      35.0    """""
# 6207  ""N""  ""2022-W05""        ""SE""       ""Sweden""      85.0    """""
# 6208  ""N""  ""2022-W05""        ""SI""     ""Slovenia""       9.0    """""
# 6209  ""N""  ""2022-W05""        ""SK""     ""Slovakia""       0.0    """""
#
# [6210 rows x 9 columns]

# %%
#Clean data

df["HealthTopic"] = df["HealthTopic"].str.replace('"', '')
df["Population"] = df["Population"].str.replace('""', '')
df["Indicator"] = df["Indicator"].str.replace('""', '')
df["Unit"] = df["Unit"].str.replace('""', '')
df["Time"] = df["Time"].str.replace('""', '')
df["RegionCode"] = df["RegionCode"].str.replace('""', '')
df["RegionName"] = df["RegionName"].str.replace('""', '')
df["TxtValue"] = df["TxtValue"].str.replace('""', '')

# %%
#Make overview of included nations
nations = df.drop_duplicates("RegionName",keep='first')
nations = nations.drop(["HealthTopic","Population","Indicator", "Unit","Time","NumValue","TxtValue"], axis=1)
nations
# Out:
#      RegionCode   RegionName
# 0            DE      Germany
# 1            DK      Denmark
# 2            EE      Estonia
# 3            EL       Greece
# 4            ES        Spain
# 5      EU31_UKX       EU/EEA
# 6            FI      Finland
# 7            FR       France
# 8            IE      Ireland
# 9            LT    Lithuania
# 10           LV       Latvia
# 11           NL  Netherlands
# 12           PL       Poland
# 13           PT     Portugal
# 14           SE       Sweden
# 15           SI     Slovenia
# 25           IT        Italy
# 32           CZ      Czechia
# 48           SK     Slovakia
# 58           HU      Hungary
# 163          MT        Malta
# 204          RO      Romania
# 217          IS      Iceland
# 313          BG     Bulgaria
# 1870         CY       Cyprus
# 2683         LU   Luxembourg
# 3354         BE      Belgium
# 5124         HR      Croatia

# %%
# Add week and year column for plotting
def addweek(str):
    week = str[-2:]
    return int(week)

df["Week"] = df.Time.apply(addweek)

def addyear(str):
    year = str[:4]
    return int(year)

df["Year"] = df.Time.apply(addyear)

# %%
# Fix Time

def timefix(str):
    year = str[:4]
    week = str[-2:]
    return year+week

df["Time"] = df.Time.apply(timefix)
df['Time'] = pd.to_datetime(df.Time.astype(str)+'7',format='%G%V%u')

# %%
#Make dic of all nations in each year
Nations = nations["RegionCode"]
Nat_dic = {}
for N in Nations:
    df_N = df.loc[df['RegionCode'] == N]
    df_N
    
    N_year_dic = {}
    for year_i in range(2014,2023):
        N_year_i = df_N.loc[df_N['Year'] == year_i]
        N_year_dic[year_i] = N_year_i
    Nat_dic[N]= N_year_dic

# %%
# Look for Nations with high number of found cases
n_test3 = np.array([])
nat = np.array([])
for N in Nations:
    S = Nat_dic[N][2019]["NumValue"].sum()+Nat_dic[N][2018]["NumValue"].sum()+Nat_dic[N][2017]["NumValue"].sum()
    n_test3 = np.append(n_test3,S)
    nat = np.append(nat,N)
    
df_test = pd.DataFrame({
    'Nation':nat,
    'Sum':n_test3
})
df_test = df_test.set_index("Nation")
df_test.sort_values("Sum",ascending=False)
# Out:
#                Sum
# Nation
# EU31_UKX  101782.0
# FR         36423.0
# SE         18390.0
# ES         12301.0
# DK         11973.0
# NL          5358.0
# IE          4430.0
# SI          4232.0
# PT          3850.0
# LV          1303.0
# EE          1229.0
# IS           696.0
# BG           329.0
# DE           322.0
# CY           286.0
# HU           191.0
# RO           148.0
# PL           143.0
# SK            62.0
# LU            48.0
# MT            38.0
# LT            22.0
# BE            20.0
# CZ            15.0
# EL            15.0
# FI             6.0
# IT             0.0
# HR             0.0

# %%
# Isolate country (Danmark = "DK", Sverige = "SE", Tyskland = "DE", Finland = "FI" )
Nations = ["DK", "SE", "DE", "FR"]
Nat_dic = {}
for N in Nations:
    df_N = df.loc[df['RegionCode'] == N]
    df_N
    
    N_year_dic = {}
    for year_i in range(2014,2023):
        N_year_i = df_N.loc[df_N['Year'] == year_i]
        N_year_dic[year_i] = N_year_i
    Nat_dic[N]= N_year_dic

# %%
#Make dictonary for selected contry with year sections

# dk_year_dic = {}

# for year_i in range(2014,2023):
#     dk_year_i = df_DK.loc[df_DK['Year'] == year_i]
#     dk_year_dic[year_i] = dk_year_i

    
### This datetime fix messes up the weeks.
# for year_i in range(2014,2023):
#      dk_year_i = df_DK.loc[pd.DatetimeIndex(df_DK['Time']).year == year_i]
#      dk_year_dic[year_i] = dk_year_i

# %%
# %matplotlib inline

# %%
#Make figure with the 4 chosen countries
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(30,20))

for year_i in range(2014,2023):
    ax1.plot(Nat_dic[Nations[0]][year_i]["Week"],Nat_dic[Nations[0]][year_i]["NumValue"],"-")
ax1.legend(range(2014,2023))
ax1.set_xlabel('Uge nr')
ax1.set_ylabel('RSV opdaget (N)')
ax1.set_title(Nat_dic[Nations[0]][2020]["RegionName"].iloc[1])

for year_i in range(2014,2023):
    ax2.plot(Nat_dic[Nations[1]][year_i]["Week"],Nat_dic[Nations[1]][year_i]["NumValue"],"-")
ax2.legend(range(2014,2023))
ax2.set_xlabel('Uge nr')
ax2.set_ylabel('RSV opdaget (N)')
ax2.set_title(Nat_dic[Nations[1]][2020]["RegionName"].iloc[1])

for year_i in range(2014,2023):
    ax3.plot(Nat_dic[Nations[2]][year_i]["Week"],Nat_dic[Nations[2]][year_i]["NumValue"],"-")
ax3.legend(range(2014,2023))
ax3.set_xlabel('Uge nr')
ax3.set_ylabel('RSV opdaget (N)')
ax3.set_title(Nat_dic[Nations[2]][2020]["RegionName"].iloc[1])



for year_i in range(2014,2023):
    ax4.plot(Nat_dic[Nations[3]][year_i]["Week"],Nat_dic[Nations[3]][year_i]["NumValue"],"-")
ax4.legend(range(2014,2023))
ax4.set_xlabel('Uge nr')
ax4.set_ylabel('RSV opdaget (N)')
ax4.set_title(Nat_dic[Nations[3]][2020]["RegionName"].iloc[1])

plt.savefig('RSV_Lande.png', dpi=300)

# %%
# fig, ax5 = plt.subplots(1,1,figsize=(12,5))
# for year_i in range(2014,2023):
#     ax5.plot(Nat_dic[Nations[2]][year_i]["Week"],Nat_dic[Nations[2]][year_i]["NumValue"],"-")
# ax5.legend(range(2014,2023))
# ax5.set_xlabel('Uge nr')
# ax5.set_ylabel('RSV opdaget (N)')
# ax5.set_title(Nat_dic[Nations[2]][2020]["RegionName"].iloc[1])
# Out:
# Text(0.5, 1.0, 'Germany')

# %%
data = []
for y_i in range(2014,2023):
    test_year = Nat_dic["DE"][y_i]["NumValue"].sum()
    
    data.append([int(y_i), test_year])

df = pd.DataFrame(data, columns=['Year', 'Tests'])

# %%
fig = plt.figure(figsize=(25,7))

ax5 = fig.add_subplot(121)
for year_i in range(2014,2023):
    ax5.plot(Nat_dic[Nations[2]][year_i]["Week"],Nat_dic[Nations[2]][year_i]["NumValue"],"-")
ax5.legend(range(2014,2023))
ax5.set_xlabel('Uge nr')
ax5.set_ylabel('RSV opdaget (N)')
ax5.set_title(Nat_dic[Nations[2]][2020]["RegionName"].iloc[1])

ax6 = fig.add_subplot(122)
font_size=14
bbox=[0, 0, 1, 1]
ax6.axis('off')
mpl_table = ax6.table(cellText = df.values, bbox=bbox, colLabels=df.columns)
mpl_table.auto_set_font_size(True)
mpl_table.set_fontsize(font_size)
plt.savefig('Germany.png', dpi=300)

# %%
df_ty
# Out:
#         0 Tests Year
# 0  2014.0   NaN  NaN
# 1  2015.0   NaN  NaN
# 2  2016.0   NaN  NaN
# 3  2017.0   NaN  NaN
# 4  2018.0   NaN  NaN
# 5  2019.0   NaN  NaN
# 6  2020.0   NaN  NaN
# 7  2021.0   NaN  NaN
# 8  2022.0   NaN  NaN
