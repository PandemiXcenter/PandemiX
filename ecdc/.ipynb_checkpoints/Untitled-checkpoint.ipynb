# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

import requests

import datetime as dt
# import scipy.stats as stats 
# import os
# import random
# import math
# import itertools as it

from scipy.optimize import curve_fit

# %%
#Settings for plotting

fs_label = 16

parameters = {                
                'figure.titlesize': fs_label+6,
                'axes.labelsize': fs_label,
                'axes.titlesize': fs_label+4,
                'xtick.labelsize': fs_label,
                'ytick.labelsize': fs_label, 
                'legend.fontsize': fs_label
             }

plt.rcParams.update(parameters)

saveplots = True
save_loc = "figs/"
save_formats = ["pdf", "png"]

# rcParams.keys()

# locale.setlocale(locale.LC_TIME, "Danish")

# %%
def download_url(url, save_path, chunk_size=128):
    r = requests.get(url, stream=True)
    with open(save_path, 'wb') as fd:
        for chunk in r.iter_content(chunk_size=chunk_size):
            fd.write(chunk)


yearweek_to_date = lambda d, weekday="-1": dt.datetime.strptime(d + weekday, "%Y-%W-%w")
#this is stolen from rasmus' notebook
# yearweek_to_date = lambda x: dt.date.fromisocalendar(int(x[:4]),int(x[5:]),1)

#def getPercVar(df,country_code,variant):
#    curDF = getBestDatabase(df,country_code,variant)
#     return (curDF.Dates,curDF.percent_variant2)


# Model tests
def logiModel(x,alpha,y0):
    parenthesis = (1-y0)/y0
    return 1/(1+parenthesis*np.exp(-alpha*x))

#def date_window(start_date=first_date, stop_date=last_date):

# %%
url = "https://opendata.ecdc.europa.eu/covid19/virusvariant/csv/data.csv"
path=""
filename="variants_data.csv"
download_url(url, path+filename)

# %%
df = pd.read_csv(path+filename)

countries = df.country.unique() 
#countries = ["Denmark", "Norway", "Sweden", "Finland"]
# country_codes = ["DK", "NO", "SE", "FI"]
# variants = df.variant.unique() 
variants = ['B.1.1.7', 'B.1.617.2']
# print(df.variant.unique())

windows = [("2020-11-01", "2021-05-01"), 
           ("2021-03-01", "2021-06-28")]

# select data to plot:
filt = (df.country.isin(countries) & df.variant.isin(variants))
df = df[filt]

# generate what is needed, clean out what is not
df["date"] = df.year_week.apply(yearweek_to_date)
df['percent_variant'] = np.divide(df.number_detections_variant, df.number_sequenced)

df.drop(columns=["year_week", "country_code"], inplace=True)

# print(df.date.tail())
df
# Out:
#        country  source  new_cases  number_sequenced  percent_cases_sequenced  \
# 0      Austria  GISAID     5152.0                 4                      0.1
# 9      Austria  GISAID     5152.0                 4                      0.1
# 17     Austria  GISAID     7365.0                24                      0.3
# 26     Austria  GISAID     7365.0                24                      0.3
# 34     Austria  GISAID     9574.0                41                      0.4
# ...        ...     ...        ...               ...                      ...
# 23966   Sweden   TESSy     2746.0               908                     33.1
# 23968   Sweden   TESSy     1881.0               232                     12.3
# 23971   Sweden   TESSy     1881.0               232                     12.3
# 23973   Sweden   TESSy     2070.0                27                      1.3
# 23974   Sweden   TESSy     2070.0                27                      1.3
#
# ...

# %%
num_seq_df = df.loc[df.groupby(["country", "variant", "date"])["number_sequenced"].idxmax()]

window_df = pd.DataFrame(columns=["variant", "window_start", "window_stop"]) #, "po"])
for i, v in enumerate(variants):
    data_dict = dict(zip(window_df.columns, [v, windows[i][0], windows[i][1]]))
    window_df = window_df.append(data_dict, ignore_index=True)

#window_df = pd.DataFrame(columns=["country", "variant", "window_start", "window_stop"])    
#window_df = window_df.append(data_dict, ignore_index=True)


#select on variants and countries:
fig, axs = plt.subplots(len(countries), len(variants), 
                        figsize=(4*len(variants), 3*len(countries)), tight_layout=True, sharex=True)
for i,c in enumerate(countries):
    for j,v in enumerate(variants):
        w_start, w_stop = list(window_df.loc[(window_df.variant==v), ["window_start", "window_stop"]].iloc[0])
        date_filt = (num_seq_df.date > w_start) & (num_seq_df.date <= w_stop)
        cv_filt = (num_seq_df.country==c)&(num_seq_df.variant==v)

        # performing the dataplots associated w a particular strain and country:
        axs[i][j].plot(num_seq_df.loc[cv_filt&date_filt, "date"], num_seq_df.loc[cv_filt&date_filt, "percent_variant"], 
                       marker="o", linestyle=":", label="max")
        axs[i][j].tick_params(axis='x', labelrotation=90)
        
        # performing fitting procedure and plotting of fit:
        p0 = None #[0.04847447, 0.00290781]
        X_data = num_seq_df.loc[cv_filt&date_filt, "date"].fillna(0).values
        Y_data = num_seq_df.loc[cv_filt&date_filt, "percent_variant"].fillna(0).values
        X_data_num = (pd.to_datetime(X_data) - pd.to_datetime(X_data[0])) / np.timedelta64(1,'D')

        popt, pcov = curve_fit(logiModel, X_data_num, Y_data, p0=p0, maxfev=1200)
        axs[i][j].plot(X_data, logiModel(X_data_num, *popt))
        
for ax, v in zip(axs[0], variants):
    ax.set_title(v)
    
for ax, c in zip(axs[:,-1], countries):
    ax2 = ax.twinx() 
    ax2.tick_params(right=False, labelright=False)
    ax2.set_ylabel(c)

# plt.legend()

num_seq_df
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-34-94de63d5584d> in <module>
#      30         X_data_num = (pd.to_datetime(X_data) - pd.to_datetime(X_data[0])) / np.timedelta64(1,'D')
#      31
# ---> 32         popt, pcov = curve_fit(logiModel, X_data_num, Y_data, p0=p0, maxfev=1200)
#      33         axs[i][j].plot(X_data, logiModel(X_data_num, *popt))
#      34
#
# /usr/lib/python3/dist-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     787         cost = np.sum(infodict['fvec'] ** 2)
#     788         if ier not in [1, 2, 3, 4]:
# --> 789             raise RuntimeError("Optimal parameters not found: " + errmsg)
#     790     else:
#     791         # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#
# ...

# %%
num_seq_df = df.loc[df.groupby(["country", "variant", "date"])["number_sequenced"].idxmax()]

window_df = pd.DataFrame(columns=["variant", "window_start", "window_stop"]) #, "po"])
for i, v in enumerate(variants):
    data_dict = dict(zip(window_df.columns, [v, windows[i][0], windows[i][1]]))
    window_df = window_df.append(data_dict, ignore_index=True)

#window_df = pd.DataFrame(columns=["country", "variant", "window_start", "window_stop"])    
#window_df = window_df.append(data_dict, ignore_index=True)


#select on variants and countries:
fig, axs = plt.subplots(len(countries), len(variants), 
                        figsize=(4*len(variants), 3*len(countries)), tight_layout=True, sharex=True)
for i,c in enumerate(countries):
    for j,v in enumerate(variants):
        w_start, w_stop = list(window_df.loc[(window_df.variant==v), ["window_start", "window_stop"]].iloc[0])
        date_filt = (num_seq_df.date > w_start) & (num_seq_df.date <= w_stop)
        cv_filt = (num_seq_df.country==c)&(num_seq_df.variant==v)

        # performing the dataplots associated w a particular strain and country:
        axs[i][j].plot(num_seq_df.loc[cv_filt&date_filt, "date"], num_seq_df.loc[cv_filt&date_filt, "percent_variant"], 
                       marker="o", linestyle=":", label="max")
        axs[i][j].tick_params(axis='x', labelrotation=90)
        
        # performing fitting procedure and plotting of fit:
        p0 = None #[0.04847447, 0.00290781]
        X_data = num_seq_df.loc[cv_filt&date_filt, "date"].fillna(0).values
        Y_data = num_seq_df.loc[cv_filt&date_filt, "percent_variant"].fillna(0).values
        Y_data = Y_data/(1-Y_data)
        X_data_num = (pd.to_datetime(X_data) - pd.to_datetime(X_data[0])) / np.timedelta64(1,'D')

        popt, pcov = curve_fit(lambda x, a, b: a*x + b, X_data_num, Y_data, p0=p0, maxfev=1200)
        axs[i][j].plot(X_data, logiModel(X_data_num, *popt))
        
for ax, v in zip(axs[0], variants):
    ax.set_title(v)
    
for ax, c in zip(axs[:,-1], countries):
    ax2 = ax.twinx() 
    ax2.tick_params(right=False, labelright=False)
    ax2.set_ylabel(c)

# plt.legend()

num_seq_df
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:30: RuntimeWarning: divide by zero encountered in true_divide
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-3e489605dd71> in <module>
#      31         X_data_num = (pd.to_datetime(X_data) - pd.to_datetime(X_data[0])) / np.timedelta64(1,'D')
#      32
# ---> 33         popt, pcov = curve_fit(lambda x, a, b: a*x + b, X_data_num, Y_data, p0=p0, maxfev=1200)
#      34         axs[i][j].plot(X_data, logiModel(X_data_num, *popt))
#      35
#
# /usr/lib/python3/dist-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     732     # NaNs cannot be handled
#     733     if check_finite:
# --> 734         ydata = np.asarray_chkfinite(ydata, float)
#     735     else:
#     736         ydata = np.asarray(ydata, float)
#
# ...
