# %%
# Main notebook for playing around looking at different things in data
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.min_rows', 50)
import seaborn as sns


import matplotlib.pyplot as plt
# %matplotlib widget
plt.rcParams['figure.figsize'] = (12,8)
# plt.rcParams["image.cmap"] = "Dark2"
# plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Dark2.colors)
plt.rcParams["image.cmap"] = "tab10"
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.tab10.colors)
fs_label = 16
parameters = {
                'axes.labelsize': fs_label,
                'axes.titlesize': fs_label+4,
                'xtick.labelsize': fs_label,
                'ytick.labelsize': fs_label, 
                'legend.fontsize': fs_label, 
                'lines.markersize': 10,
                'lines.linewidth': 3
             }
plt.rcParams.update(parameters)
# %matplotlib widget  
# plt.style.use('ggplot')
import matplotlib.colors as colors
# cmap = plt.cm.get_cmap('Dark2',len(ageGroups))
from matplotlib import cm # Colormaps

import locale
import matplotlib.dates as mdates
locale.setlocale(locale.LC_TIME,"Danish")
# ax = plt.gca()
# ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b\n%Y'))
# # ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y \n %B'))

import os
# import csv
import math


from datetime import date


saveFigures = True
# saveFigures = False
print('saveFigures is set to: '+str(saveFigures))

print('Done loading packages')

def rnMean(data,meanWidth):
    return np.convolve(data, np.ones(meanWidth)/meanWidth, mode='valid')
def rnTime(t,meanWidth):
    return t[math.floor(meanWidth/2):-math.ceil(meanWidth/2)+1]
# Out:
# saveFigures is set to: True
# Done loading packages

# %%
curFilename = "C:\\Users\\rakrpe\\Documents\\PandemiX\\GithubRepos\\PandemiX\\DanskeData\\ssi_dashboard\\SSI_dashboard_2021-10-25\\Regionalt_DB\\02_hospitalsbelaegning.csv"

# %%
# Collect the cases, tests and positive percentage from all the "cases by age" files

ssidatapath = "ssi_dashboard"
rootdir = os.getcwd() +"\\" + ssidatapath

curDates = []
curIndlagt = []
for subdir, dirs, files in os.walk(rootdir):
    if not len(files) == 0:
        latestdir = subdir.rsplit('\\',1)[0]
        # latestDate = pd.to_datetime(subdir[-10:])
        latestDate = pd.to_datetime(latestdir[-10:])
        # print(latestDate)
        try:
            curdf = pd.read_csv(latestdir+'\\Regionalt_DB\\02_hospitalsbelaegning.csv',delimiter = ';',encoding='latin1',dtype=str)
        except:
            print(latestdir)
            
            
        curDates.append(latestDate)
        
        numIndlagt = pd.to_numeric(curdf.Indlagte).sum()
            
        curIndlagt.append(numIndlagt)
        # curdf['Antal_bekræftede_COVID-19'] = pd.to_numeric(curdf['Antal_bekræftede_COVID-19'].astype(str).apply(lambda x: x.replace('.','')))
        # curdf['Antal_testede'] = pd.to_numeric(curdf['Antal_testede'].astype(str).apply(lambda x: x.replace('.','')))
        # curdf['Procent_positive'] = pd.to_numeric(curdf['Procent_positive'].astype(str).apply(lambda x: x.replace(',','.')))
        
        
        # dfCase.loc[latestDate] = curdf['Antal_bekræftede_COVID-19'].values
        # dfTest.loc[latestDate] = curdf['Antal_testede'].values
        # dfPosP.loc[latestDate] = curdf['Procent_positive'].values

# allDates = dfCase.index
# Out:
# c:\Users\rakrpe\Documents\PandemiX\GithubRepos\PandemiX\DanskeData\ssi_dashboard\SSI_dashboard_2021-05-25
# c:\Users\rakrpe\Documents\PandemiX\GithubRepos\PandemiX\DanskeData\ssi_dashboard\SSI_dashboard_2021-05-25

# %%
# latestdir[0][-10:]
# latestdir[0]+'Regionalt_DB\\02_hospitalsbelaegning.csv'

# %%
fig,ax1 = plt.subplots()

ax1.plot(curDates,curIndlagt)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Collect the cases, tests and positive percentage from all the "cases by age" files

ssidatapath = "ssi_dashboard"
rootdir = os.getcwd() +"\\" + ssidatapath

# curDates = []
# curIndlagt = []
for subdir, dirs, files in os.walk(rootdir):
    if not len(files) == 0:
        latestdir = subdir.rsplit('\\',1)[0]
        # latestDate = pd.to_datetime(subdir[-10:])
        latestDate = pd.to_datetime(latestdir[-10:])
        # print(latestDate)
        # try:
        #     curdf = pd.read_csv(latestdir+'\\Regionalt_DB\\15_indlagte_pr_region_pr_dag.csv',delimiter = ';',encoding='latin1',dtype=str)
        # except:
        #     print(latestdir)
            
            
        # curDates.append(latestDate)
        
        # numIndlagt = pd.to_numeric(curdf.Indlagte).sum()
            
        # curIndlagt.append(numIndlagt)
        # curdf['Antal_bekræftede_COVID-19'] = pd.to_numeric(curdf['Antal_bekræftede_COVID-19'].astype(str).apply(lambda x: x.replace('.','')))
        # curdf['Antal_testede'] = pd.to_numeric(curdf['Antal_testede'].astype(str).apply(lambda x: x.replace('.','')))
        # curdf['Procent_positive'] = pd.to_numeric(curdf['Procent_positive'].astype(str).apply(lambda x: x.replace(',','.')))
        
        
        # dfCase.loc[latestDate] = curdf['Antal_bekræftede_COVID-19'].values
        # dfTest.loc[latestDate] = curdf['Antal_testede'].values
        # dfPosP.loc[latestDate] = curdf['Procent_positive'].values

# allDates = dfCase.index
curdf = pd.read_csv(latestdir+'\\Regionalt_DB\\15_indlagte_pr_region_pr_dag.csv',delimiter = ';',encoding='latin1',dtype=str)
curdf['Dato'] = pd.to_datetime(curdf['Dato'])
curdf['Indlagte'] = pd.to_numeric(curdf['Indlagte'])

# %%
firstDate = np.datetime64(curdf.Dato.min())
lastDate = np.datetime64(curdf.Dato.max())

dateRange = np.arange(firstDate,lastDate,np.timedelta64(1,'D'))
# dateRange

# %%
allCount = [] 
for curDate in dateRange:
    thisdf = curdf[curdf.Dato == curDate]
    
    thisCount = thisdf.Indlagte.sum()
    allCount.append(thisCount)

# %%
# fig,ax1 = plt.subplots(figsize=(6,10))
# prevYearIndex = (dateRange < np.datetime64('2021-01-01'))
# prevYearDates = dateRange[prevYearIndex]
# prevYearSum = allCount[prevYearIndex]
# # prevYearPos = 100 * np.divide(prevYearSum,prevYearTest)

# thisYearIndex = (dateRange >= np.datetime64('2021-01-01'))
# thisYearDates = dateRange[thisYearIndex]
# thisYearSum = allCount[thisYearIndex]
# thisYearTest = curdf[thisYearIndex]['Tested']
# # thisYearPos = curdf[thisYearIndex]['PosPct']
# thisYearPos = 100 * np.divide(thisYearSum,thisYearTest)

# ax1.plot(dateRange,allCount)
allCount
# Out:
# [527,
#  511,
#  498,
#  490,
#  488,
#  466,
#  446,
#  427,
#  398,
#  402,
#  391,
#  381,
#  374,
#  355,
#  341,
#  337,
#  304,
#  303,
#  321,
#  315,
#  309,
#  303,
#  303,
#  276,
#  273,
#  293,
#  271,
#  254,
#  236,
#  229,
#  214,
#  225,
#  228,
#  209,
#  190,
#  178,
#  183,
#  169,
#  174,
#  173,
#  151,
#  138,
#  128,
#  120,
#  115,
#  113,
#  118,
#  115,
#  103,
#  100,
#  100,
#  102,
#  100,
#  102,
#  97,
#  91,
#  96,
#  93,
#  87,
#  85,
#  88,
#  86,
#  82,
#  76,
#  66,
#  68,
#  65,
#  66,
#  59,
#  57,
#  51,
#  51,
#  47,
#  49,
#  46,
#  43,
#  39,
#  38,
#  37,
#  39,
#  38,
#  37,
#  32,
#  33,
#  36,
#  31,
#  29,
#  30,
#  35,
#  32,
#  29,
#  29,
#  27,
#  26,
#  24,
#  23,
#  17,
#  18,
#  18,
#  17,
#  15,
#  18,
#  18,
#  17,
#  19,
#  17,
#  20,
#  16,
#  19,
#  18,
#  18,
#  16,
#  19,
#  16,
#  17,
#  23,
#  23,
#  22,
#  21,
#  18,
#  18,
#  16,
#  20,
#  24,
#  24,
#  23,
#  24,
#  25,
#  21,
#  20,
#  23,
#  20,
#  16,
#  13,
#  14,
# ...

# %% [markdown]
# # Indlæggelser per aldersgruppe

# %%
ssidatapath = "ssi_dashboard"
rootdir = os.getcwd() +"\\" + ssidatapath

curFileName = '\\Regionalt_DB\\04_indlagte_pr_alders_grp_pr_region.csv'

alldfs = []



allDates = []


for f in os.scandir(rootdir):
    curPath = f.path
    latestdir = curPath
    try:
        curDate = pd.to_datetime(curPath[-10:])

        
        curcsvpath = curPath + curFileName
        curdf = pd.read_csv(curcsvpath,delimiter = ';',dtype=str,encoding='latin-1')

        allDates.append(curDate)
        alldfs.append(curdf)
    except:
        print(curPath)
    
print(f'Number of dataframes in alldfs: {len(alldfs)}')
# Out:
# c:\Users\rakrpe\Documents\PandemiX\GithubRepos\PandemiX\DanskeData\ssi_dashboard\SSI_dashboard_2021-05-25
# Number of dataframes in alldfs: 161

# %%
numDataframe = len(alldfs)

# Whole country, age-split
allAge = curdf['Alders gruppe'].unique()

# dfCase = pd.DataFrame()
# dfDeath = pd.DataFrame()


# dfCase['Dato'] = allDates
# dfDeath['Dato'] = allDates

dfAdm = pd.DataFrame()
dfAdm['Dato'] = allDates

for ag in range(len(allAge)):
    curAge = allAge[ag]

    allAdm = []
    prevDate = allDates[0]

    for da in range(0,numDataframe):
        thisdf = alldfs[da]
        thisdf = thisdf[thisdf['Alders gruppe'] == curAge]

        thisCase = thisdf['Indlæggelser'].astype(int).sum()
        # thisDeaths = thisdf['Døde'].astype(int).sum()


        allAdm.append(thisCase)

    
    dfAdm[curAge] = allAdm
# dfAdm

# %%
# dfAdm.diff().plot(x='Dato') 
# dfAdmDiff = dfAdm.diff().iloc[1:,1:]

# dfAdmDiff
dfAdm
# Out:
#           Dato  0-9  10-19  20-29  30-39  40-49  50-59  60-69  70-79  80-89  \
# 0   2021-03-08  167    165    512    787   1163   1860   2012   2902   2435
# 1   2021-03-09  167    165    513    788   1167   1861   2015   2909   2438
# 2   2021-03-10  167    167    518    791   1171   1870   2021   2911   2437
# 3   2021-03-11  168    167    521    792   1178   1875   2025   2913   2441
# 4   2021-03-12  168    168    523    795   1180   1883   2031   2919   2444
# 5   2021-03-15  169    169    527    804   1187   1895   2041   2933   2449
# 6   2021-03-16  169    169    528    806   1192   1906   2043   2940   2453
# 7   2021-03-17  170    169    530    810   1197   1912   2045   2948   2456
# 8   2021-03-18  170    171    530    811   1201   1922   2048   2955   2458
# 9   2021-03-19  170    171    532    812   1206   1929   2054   2960   2463
# 10  2021-03-22  171    173    535    818   1217   1942   2067   2969   2470
# ...

# %%
# Collect the cases, tests and positive percentage from all the "cases by age" files

ssidatapath = "ssi_dashboard"
rootdir = os.getcwd() +"\\" + ssidatapath


hospdf = pd.DataFrame(columns=ageGroups)

curDates = []
curIndlagt = []
for subdir, dirs, files in os.walk(rootdir):
    if not len(files) == 0:
        latestdir = subdir.rsplit('\\',1)[0]
        # latestDate = pd.to_datetime(subdir[-10:])
        latestDate = pd.to_datetime(latestdir[-10:])
        # print(latestDate)
        try:
            curdf = pd.read_csv(latestdir+'\\Regionalt_DB\\04_indlagte_pr_alders_grp_pr_region.csv',delimiter = ';',encoding='latin1',dtype=str)
            curdf['Indlæggelser'] = pd.to_numeric(curdf['Indlæggelser'])
            thisdf = curdf.groupby('Alders gruppe').sum()    
            
            curDates.append(latestDate)
            
        except:
            print(latestdir)
            
        
        # hospdf[latestDate] = thisdf.transpose()
        # numIndlagt = pd.to_numeric(curdf.Indlagte).sum()
            
        # curIndlagt.append(numIndlagt)
        # curdf['Antal_bekræftede_COVID-19'] = pd.to_numeric(curdf['Antal_bekræftede_COVID-19'].astype(str).apply(lambda x: x.replace('.','')))
        # curdf['Antal_testede'] = pd.to_numeric(curdf['Antal_testede'].astype(str).apply(lambda x: x.replace('.','')))
        # curdf['Procent_positive'] = pd.to_numeric(curdf['Procent_positive'].astype(str).apply(lambda x: x.replace(',','.')))
        
        
        # dfCase.loc[latestDate] = curdf['Antal_bekræftede_COVID-19'].values
        # dfTest.loc[latestDate] = curdf['Antal_testede'].values
        # dfPosP.loc[latestDate] = curdf['Procent_positive'].values

# allDates = dfCase.index
curDates
# Out:
# c:\Users\rakrpe\Documents\PandemiX\GithubRepos\PandemiX\DanskeData\ssi_dashboard\SSI_dashboard_2021-05-25
# c:\Users\rakrpe\Documents\PandemiX\GithubRepos\PandemiX\DanskeData\ssi_dashboard\SSI_dashboard_2021-05-25
# [Timestamp('2021-03-08 00:00:00'),
#  Timestamp('2021-03-08 00:00:00'),
#  Timestamp('2021-03-09 00:00:00'),
#  Timestamp('2021-03-09 00:00:00'),
#  Timestamp('2021-03-10 00:00:00'),
#  Timestamp('2021-03-10 00:00:00'),
#  Timestamp('2021-03-11 00:00:00'),
#  Timestamp('2021-03-11 00:00:00'),
#  Timestamp('2021-03-12 00:00:00'),
#  Timestamp('2021-03-12 00:00:00'),
#  Timestamp('2021-03-15 00:00:00'),
#  Timestamp('2021-03-15 00:00:00'),
#  Timestamp('2021-03-16 00:00:00'),
#  Timestamp('2021-03-16 00:00:00'),
#  Timestamp('2021-03-17 00:00:00'),
#  Timestamp('2021-03-17 00:00:00'),
#  Timestamp('2021-03-18 00:00:00'),
#  Timestamp('2021-03-18 00:00:00'),
#  Timestamp('2021-03-19 00:00:00'),
#  Timestamp('2021-03-19 00:00:00'),
#  Timestamp('2021-03-22 00:00:00'),
# ...

# %%
curdf['Indlæggelser'] = pd.to_numeric(curdf['Indlæggelser'])
asdf = curdf.groupby('Alders gruppe').sum().transpose()
# asdf.set_index = latestDate

ageGroups = asdf.columns
# asdf.rename(columns={'Alders gruppe': 'qwer'},inplace=True)
# asdf['Alders gruppe']
# hospdf
